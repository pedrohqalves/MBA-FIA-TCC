# %%
# !pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\quadr\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\quadr\anaconda3\lib\site-packages (from geopy) (1.50)

# %% [markdown]
# # ===============================
#
#
# # 1 . Importando as bibliotecas básicas
#
#
# # ===============================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time

# %% [markdown]
# # ==============================
#
#
# # 2. Lendo as bases de dados
#
#
# # ==============================

# %% [markdown]
# ### Primeiro lendo as bases de Clima
#
# ### No caso destas bases, temos o nome da estação, que pode ou não ser o mesmo nome da cidade que ela está localizada. Para facilitar posteriormente cruzarmos cidade a cidade com os casos de dengue, vamos usar os dados de latitude e longitude para descobrir a cidade onde está localizada a estação
#
# ### Vamos acrescentar uma coluna em cada base de cada estação mostrando cidade, estado e cep (que pode facilitar depois a localização também)

# %% [markdown]
# ## ----------------------------------------------
#
#
# ### Para cada base vamos ler o cabeçalho, retirar os dados de localização, acrescentar como colunas na base, e guardar os dados para serem empilhados com os da próxima base, e assim por diante

# %%
#Primeiro pegando uma lista com todos os arquivos na pasta onde estão os dados

dadosclima = []

import sys

root = r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima\Bases Anuais'
      
            
for root, dirs, files in os.walk(root):
     for file in files:
        dadosclima.append(os.path.join(root, file))

# %%
# Como a base de dados ficou muito grande, este comando e o seguinte devem ser rodados separadamente
# com limpeza de memória entre eles

#Importa a lib para descobrir localização através de coordenadas

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='teste_dengue')

clima = pd.DataFrame()


for i in dadosclima:
    if dadosclima.index(i) < 1000:
        
        
        
        print('Faltam ' + str(len(dadosclima) - dadosclima.index(i) +1) +' itens na lista' )
        print('Inicio Item ' + str(dadosclima.index(i)))
        inicio = time.time()
        base1 = pd.read_csv(i, delimiter = ';',engine = 'python', nrows = 3)
        base2 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 3, nrows = 4)
        estado = base1.iloc[0,1]
        estacao = base1.iloc[1,1]
        lat = str(base2.iloc[0,1]).replace(',','.')
        long = str(base2.iloc[1,1]).replace(',','.')
        
        # Tratando casos onde temos latitude que começa apenas com . ou , (positivos e negativos)
        
        if lat[0] == '.':
            lat = str(0)+lat
        elif lat[0] == '-':
            lat = '-' + str(0) + lat[1:]
        else:
            pass
        if long[0] == '.':
            long = str(0)+long
        elif long[0] == '-':
            long = '-'+ str(0) + long [1:]                
        else: 
            pass
        
        # Passa as coordenadas 
        
        location = geolocator.reverse(lat +', ' + long)
        
        
        try:
            cidade = location.raw['address']['city'] 

        except:
            cidade = 'Erro'
            
        try:
            cep = location.raw['address']['postcode'] 
        except:
            cep = 'Erro'
        
        # Pega o restante da base, e adiciona colunas com os valores que descobrimos anteriormente
        
        base3 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 8)
        base3['estacao'] = estacao
        base3['estado'] = estado
        base3['cidade'] = pd.Series()
        base3['cep'] = pd.Series()
        base3['lat'] = lat
        base3['long'] = long
        
        
        try:
            base3['cidade'] = cidade

        except:
            pass
        
        try:
            base3['cep'] = cep
        except:
            pass
        
        
        
        clima = clima.append(base3)
        fim = time.time()
        tempo = fim - inicio

        print('Fim Item ' + str(dadosclima.index(i)))
        print('Duração : ' + str(tempo) + ' segundos')
        

    else:
        pass
    


clima.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part1.csv')
del clima
# Out:
# Faltam 3652 itens na lista
# Inicio Item 0
# Fim Item 0
# Duração : 2.631844997406006 segundos
# Faltam 3651 itens na lista
# Inicio Item 1
# Fim Item 1
# Duração : 0.47897982597351074 segundos
# Faltam 3650 itens na lista
# Inicio Item 2
# Fim Item 2
# Duração : 0.4312264919281006 segundos
# Faltam 3649 itens na lista
# Inicio Item 3
# Fim Item 3
# Duração : 0.5734856128692627 segundos
# Faltam 3648 itens na lista
# Inicio Item 4
# Fim Item 4
# Duração : 0.5035779476165771 segundos
# Faltam 3647 itens na lista
# Inicio Item 5
# Fim Item 5
# Duração : 0.5084898471832275 segundos
# Faltam 3646 itens na lista
# Inicio Item 6
# Fim Item 6
# Duração : 0.5357255935668945 segundos
# Faltam 3645 itens na lista
# Inicio Item 7
# Fim Item 7
# Duração : 0.4797093868255615 segundos
# Faltam 3644 itens na lista
# Inicio Item 8
# Fim Item 8
# Duração : 0.5676727294921875 segundos
# Faltam 3643 itens na lista
# Inicio Item 9
# Fim Item 9
# Duração : 0.44829821586608887 segundos
# Faltam 3642 itens na lista
# Inicio Item 10
# Fim Item 10
# Duração : 0.5032408237457275 segundos
# Faltam 3641 itens na lista
# Inicio Item 11
# Fim Item 11
# Duração : 0.9760959148406982 segundos
# Faltam 3640 itens na lista
# Inicio Item 12
# Fim Item 12
# Duração : 0.558751106262207 segundos
# Faltam 3639 itens na lista
# Inicio Item 13
# Fim Item 13
# Duração : 0.48398637771606445 segundos
# Faltam 3638 itens na lista
# Inicio Item 14
# Fim Item 14
# Duração : 0.508225679397583 segundos
# Faltam 3637 itens na lista
# Inicio Item 15
# Fim Item 15
# Duração : 0.5299861431121826 segundos
# Faltam 3636 itens na lista
# Inicio Item 16
# Fim Item 16
# Duração : 0.6472342014312744 segundos
# Faltam 3635 itens na lista
# Inicio Item 17
# Fim Item 17
# Duração : 0.5461163520812988 segundos
# Faltam 3634 itens na lista
# Inicio Item 18
# Fim Item 18
# Duração : 0.5041983127593994 segundos
# Faltam 3633 itens na lista
# Inicio Item 19
# Fim Item 19
# Duração : 0.5031042098999023 segundos
# Faltam 3632 itens na lista
# Inicio Item 20
# Fim Item 20
# Duração : 0.5183858871459961 segundos
# Faltam 3631 itens na lista
# Inicio Item 21
# Fim Item 21
# Duração : 0.6005635261535645 segundos
# Faltam 3630 itens na lista
# Inicio Item 22
# Fim Item 22
# Duração : 0.532515287399292 segundos
# Faltam 3629 itens na lista
# Inicio Item 23
# Fim Item 23
# Duração : 0.5423798561096191 segundos
# Faltam 3628 itens na lista
# Inicio Item 24
# Fim Item 24
# Duração : 0.5281603336334229 segundos
# Faltam 3627 itens na lista
# Inicio Item 25
# Fim Item 25
# Duração : 0.5367765426635742 segundos
# Faltam 3626 itens na lista
# Inicio Item 26
# Fim Item 26
# Duração : 0.5712895393371582 segundos
# Faltam 3625 itens na lista
# Inicio Item 27
# Fim Item 27
# Duração : 0.5861461162567139 segundos
# Faltam 3624 itens na lista
# Inicio Item 28
# Fim Item 28
# Duração : 0.6228766441345215 segundos
# Faltam 3623 itens na lista
# Inicio Item 29
# Fim Item 29
# Duração : 0.5801100730895996 segundos
# Faltam 3622 itens na lista
# Inicio Item 30
# Fim Item 30
# Duração : 0.7125802040100098 segundos
# Faltam 3621 itens na lista
# Inicio Item 31
# Fim Item 31
# Duração : 0.582831621170044 segundos
# Faltam 3620 itens na lista
# Inicio Item 32
# Fim Item 32
# Duração : 0.5928988456726074 segundos
# Faltam 3619 itens na lista
# Inicio Item 33
# Fim Item 33
# Duração : 0.5905752182006836 segundos
# Faltam 3618 itens na lista
# Inicio Item 34
# Fim Item 34
# Duração : 0.6630189418792725 segundos
# Faltam 3617 itens na lista
# Inicio Item 35
# Fim Item 35
# Duração : 0.6268484592437744 segundos
# Faltam 3616 itens na lista
# Inicio Item 36
# Fim Item 36
# Duração : 0.6139793395996094 segundos
# Faltam 3615 itens na lista
# Inicio Item 37
# Fim Item 37
# Duração : 0.6107728481292725 segundos
# Faltam 3614 itens na lista
# Inicio Item 38
# Fim Item 38
# Duração : 0.6435036659240723 segundos
# Faltam 3613 itens na lista
# Inicio Item 39
# Fim Item 39
# Duração : 0.6810042858123779 segundos
# Faltam 3612 itens na lista
# Inicio Item 40
# Fim Item 40
# Duração : 0.6396288871765137 segundos
# Faltam 3611 itens na lista
# Inicio Item 41
# Fim Item 41
# Duração : 0.9791009426116943 segundos
# Faltam 3610 itens na lista
# Inicio Item 42
# Fim Item 42
# Duração : 0.6690893173217773 segundos
# Faltam 3609 itens na lista
# Inicio Item 43
# Fim Item 43
# Duração : 0.6691427230834961 segundos
# Faltam 3608 itens na lista
# Inicio Item 44
# Fim Item 44
# Duração : 0.6731634140014648 segundos
# Faltam 3607 itens na lista
# Inicio Item 45
# Fim Item 45
# Duração : 0.7947397232055664 segundos
# Faltam 3606 itens na lista
# Inicio Item 46
# Fim Item 46
# Duração : 0.6822469234466553 segundos
# Faltam 3605 itens na lista
# Inicio Item 47
# Fim Item 47
# Duração : 0.6981759071350098 segundos
# Faltam 3604 itens na lista
# Inicio Item 48
# Fim Item 48
# Duração : 0.6767334938049316 segundos
# Faltam 3603 itens na lista
# Inicio Item 49
# Fim Item 49
# Duração : 0.714895486831665 segundos
# Faltam 3602 itens na lista
# Inicio Item 50
# Fim Item 50
# Duração : 0.7844805717468262 segundos
# Faltam 3601 itens na lista
# Inicio Item 51
# Fim Item 51
# Duração : 0.7648909091949463 segundos
# Faltam 3600 itens na lista
# Inicio Item 52
# Fim Item 52
# Duração : 0.7823395729064941 segundos
# Faltam 3599 itens na lista
# Inicio Item 53
# Fim Item 53
# Duração : 0.8053295612335205 segundos
# Faltam 3598 itens na lista
# Inicio Item 54
# Fim Item 54
# Duração : 0.8037509918212891 segundos
# Faltam 3597 itens na lista
# Inicio Item 55
# Fim Item 55
# Duração : 0.8131864070892334 segundos
# Faltam 3596 itens na lista
# Inicio Item 56
# Fim Item 56
# Duração : 1.2268950939178467 segundos
# Faltam 3595 itens na lista
# Inicio Item 57
# Fim Item 57
# Duração : 0.7482540607452393 segundos
# Faltam 3594 itens na lista
# Inicio Item 58
# Fim Item 58
# Duração : 0.7448256015777588 segundos
# Faltam 3593 itens na lista
# Inicio Item 59
# Fim Item 59
# Duração : 0.7648336887359619 segundos
# Faltam 3592 itens na lista
# Inicio Item 60
# Fim Item 60
# Duração : 0.73622727394104 segundos
# Faltam 3591 itens na lista
# Inicio Item 61
# Fim Item 61
# Duração : 0.804940938949585 segundos
# Faltam 3590 itens na lista
# Inicio Item 62
# Fim Item 62
# Duração : 0.7751483917236328 segundos
# Faltam 3589 itens na lista
# Inicio Item 63
# Fim Item 63
# Duração : 0.7918641567230225 segundos
# Faltam 3588 itens na lista
# Inicio Item 64
# Fim Item 64
# Duração : 0.7722833156585693 segundos
# Faltam 3587 itens na lista
# Inicio Item 65
# Fim Item 65
# Duração : 0.8360462188720703 segundos
# Faltam 3586 itens na lista
# Inicio Item 66
# Fim Item 66
# Duração : 0.9301152229309082 segundos
# Faltam 3585 itens na lista
# Inicio Item 67
# Fim Item 67
# Duração : 0.9072706699371338 segundos
# Faltam 3584 itens na lista
# Inicio Item 68
# Fim Item 68
# Duração : 0.9263901710510254 segundos
# Faltam 3583 itens na lista
# Inicio Item 69
# Fim Item 69
# Duração : 0.8748619556427002 segundos
# Faltam 3582 itens na lista
# Inicio Item 70
# Fim Item 70
# Duração : 0.8198685646057129 segundos
# Faltam 3581 itens na lista
# Inicio Item 71
# Fim Item 71
# Duração : 0.8323748111724854 segundos
# Faltam 3580 itens na lista
# Inicio Item 72
# Fim Item 72
# Duração : 0.8832228183746338 segundos
# Faltam 3579 itens na lista
# Inicio Item 73
# Fim Item 73
# Duração : 0.8275351524353027 segundos
# Faltam 3578 itens na lista
# Inicio Item 74
# Fim Item 74
# Duração : 0.870119571685791 segundos
# Faltam 3577 itens na lista
# Inicio Item 75
# Fim Item 75
# Duração : 0.875765323638916 segundos
# Faltam 3576 itens na lista
# Inicio Item 76
# Fim Item 76
# Duração : 0.8541126251220703 segundos
# Faltam 3575 itens na lista
# Inicio Item 77
# Fim Item 77
# Duração : 0.8699500560760498 segundos
# Faltam 3574 itens na lista
# Inicio Item 78
# Fim Item 78
# Duração : 0.8598401546478271 segundos
# Faltam 3573 itens na lista
# Inicio Item 79
# Fim Item 79
# Duração : 0.8903493881225586 segundos
# Faltam 3572 itens na lista
# Inicio Item 80
# Fim Item 80
# Duração : 0.8868780136108398 segundos
# Faltam 3571 itens na lista
# Inicio Item 81
# Fim Item 81
# Duração : 0.9022829532623291 segundos
# Faltam 3570 itens na lista
# Inicio Item 82
# Fim Item 82
# Duração : 0.8715503215789795 segundos
# Faltam 3569 itens na lista
# Inicio Item 83
# Fim Item 83
# Duração : 0.8934714794158936 segundos
# Faltam 3568 itens na lista
# Inicio Item 84
# Fim Item 84
# Duração : 0.9175856113433838 segundos
# Faltam 3567 itens na lista
# Inicio Item 85
# Fim Item 85
# Duração : 0.8986132144927979 segundos
# Faltam 3566 itens na lista
# Inicio Item 86
# Fim Item 86
# Duração : 0.9206709861755371 segundos
# Faltam 3565 itens na lista
# Inicio Item 87
# Fim Item 87
# Duração : 0.9291868209838867 segundos
# Faltam 3564 itens na lista
# Inicio Item 88
# Fim Item 88
# Duração : 0.9156901836395264 segundos
# Faltam 3563 itens na lista
# Inicio Item 89
# Fim Item 89
# Duração : 1.0102784633636475 segundos
# Faltam 3562 itens na lista
# Inicio Item 90
# Fim Item 90
# Duração : 0.979943037033081 segundos
# Faltam 3561 itens na lista
# Inicio Item 91
# Fim Item 91
# Duração : 1.5050928592681885 segundos
# Faltam 3560 itens na lista
# Inicio Item 92
# Fim Item 92
# Duração : 1.0445473194122314 segundos
# Faltam 3559 itens na lista
# Inicio Item 93
# Fim Item 93
# Duração : 1.1764400005340576 segundos
# Faltam 3558 itens na lista
# Inicio Item 94
# Fim Item 94
# Duração : 0.9218435287475586 segundos
# Faltam 3557 itens na lista
# Inicio Item 95
# Fim Item 95
# Duração : 0.9349477291107178 segundos
# Faltam 3556 itens na lista
# Inicio Item 96
# Fim Item 96
# Duração : 0.9427642822265625 segundos
# Faltam 3555 itens na lista
# Inicio Item 97
# Fim Item 97
# Duração : 1.0022809505462646 segundos
# Faltam 3554 itens na lista
# Inicio Item 98
# Fim Item 98
# Duração : 0.9658381938934326 segundos
# Faltam 3553 itens na lista
# Inicio Item 99
# Fim Item 99
# Duração : 0.9933798313140869 segundos
# Faltam 3552 itens na lista
# Inicio Item 100
# Fim Item 100
# Duração : 3.176645278930664 segundos
# Faltam 3551 itens na lista
# Inicio Item 101
# Fim Item 101
# Duração : 1.025411605834961 segundos
# Faltam 3550 itens na lista
# Inicio Item 102
# Fim Item 102
# Duração : 1.0147249698638916 segundos
# Faltam 3549 itens na lista
# Inicio Item 103
# Fim Item 103
# Duração : 1.000025749206543 segundos
# Faltam 3548 itens na lista
# Inicio Item 104
# Fim Item 104
# Duração : 0.99904465675354 segundos
# Faltam 3547 itens na lista
# Inicio Item 105
# Fim Item 105
# Duração : 1.0527606010437012 segundos
# Faltam 3546 itens na lista
# Inicio Item 106
# Fim Item 106
# Duração : 1.0113346576690674 segundos
# Faltam 3545 itens na lista
# Inicio Item 107
# Fim Item 107
# Duração : 0.9931097030639648 segundos
# Faltam 3544 itens na lista
# Inicio Item 108
# Fim Item 108
# Duração : 0.9957277774810791 segundos
# Faltam 3543 itens na lista
# Inicio Item 109
# Fim Item 109
# Duração : 1.0583631992340088 segundos
# Faltam 3542 itens na lista
# Inicio Item 110
# Fim Item 110
# Duração : 1.0136523246765137 segundos
# Faltam 3541 itens na lista
# Inicio Item 111
# Fim Item 111
# Duração : 1.0352740287780762 segundos
# Faltam 3540 itens na lista
# Inicio Item 112
# Fim Item 112
# Duração : 1.0167591571807861 segundos
# Faltam 3539 itens na lista
# Inicio Item 113
# Fim Item 113
# Duração : 1.3957939147949219 segundos
# Faltam 3538 itens na lista
# Inicio Item 114
# Fim Item 114
# Duração : 1.037410020828247 segundos
# Faltam 3537 itens na lista
# Inicio Item 115
# Fim Item 115
# Duração : 3.0062499046325684 segundos
# Faltam 3536 itens na lista
# Inicio Item 116
# Fim Item 116
# Duração : 1.0751049518585205 segundos
# Faltam 3535 itens na lista
# Inicio Item 380
# Fim Item 380
# Duração : 2.60075306892395 segundos
# Faltam 3271 itens na lista
# Inicio Item 381
# Fim Item 381
# Duração : 2.5921072959899902 segundos
# Faltam 3270 itens na lista
# Inicio Item 382
# Fim Item 382
# Duração : 2.6971683502197266 segundos
# Faltam 3269 itens na lista
# Inicio Item 383
# Fim Item 383
# Duração : 2.5889930725097656 segundos
# Faltam 3268 itens na lista
# Inicio Item 384
# Fim Item 384
# Duração : 2.599503755569458 segundos
# Faltam 3267 itens na lista
# Inicio Item 385
# Fim Item 385
# Duração : 3.1561644077301025 segundos
# Faltam 3266 itens na lista
# Inicio Item 386
# Fim Item 386
# Duração : 2.7150461673736572 segundos
# Faltam 3265 itens na lista
# Inicio Item 387
# Fim Item 387
# Duração : 2.614900588989258 segundos
# Faltam 3264 itens na lista
# Inicio Item 388
# Fim Item 388
# Duração : 2.6781556606292725 segundos
# Faltam 3263 itens na lista
# Inicio Item 389
# Fim Item 389
# Duração : 2.5783867835998535 segundos
# Faltam 3262 itens na lista
# Inicio Item 390
# Fim Item 390
# Duração : 2.7975704669952393 segundos
# Faltam 3261 itens na lista
# Inicio Item 391
# Fim Item 391
# Duração : 2.6953768730163574 segundos
# Faltam 3260 itens na lista
# Inicio Item 392
# Fim Item 392
# Duração : 2.652961254119873 segundos
# Faltam 3259 itens na lista
# Inicio Item 393
# Fim Item 393
# Duração : 2.65063738822937 segundos
# Faltam 3258 itens na lista
# Inicio Item 394
# Fim Item 394
# Duração : 2.705479145050049 segundos
# Faltam 3257 itens na lista
# Inicio Item 395
# Fim Item 395
# Duração : 2.8777480125427246 segundos
# Faltam 3256 itens na lista
# Inicio Item 396
# Fim Item 396
# Duração : 2.7269511222839355 segundos
# Faltam 3255 itens na lista
# Inicio Item 397
# Fim Item 397
# Duração : 2.637284517288208 segundos
# Faltam 3254 itens na lista
# Inicio Item 398
# Fim Item 398
# Duração : 2.8587920665740967 segundos
# Faltam 3253 itens na lista
# Inicio Item 399
# Fim Item 399
# Duração : 3.1945977210998535 segundos
# Faltam 3252 itens na lista
# Inicio Item 400
# Fim Item 400
# Duração : 2.7333521842956543 segundos
# Faltam 3251 itens na lista
# Inicio Item 401
# Fim Item 401
# Duração : 2.6602022647857666 segundos
# Faltam 3250 itens na lista
# Inicio Item 402
# Fim Item 402
# Duração : 2.8208749294281006 segundos
# Faltam 3249 itens na lista
# Inicio Item 403
# Fim Item 403
# Duração : 2.70885968208313 segundos
# Faltam 3248 itens na lista
# Inicio Item 404
# Fim Item 404
# Duração : 2.719810724258423 segundos
# Faltam 3247 itens na lista
# Inicio Item 405
# Fim Item 405
# Duração : 2.733959436416626 segundos
# Faltam 3246 itens na lista
# Inicio Item 406
# Fim Item 406
# Duração : 2.868647336959839 segundos
# Faltam 3245 itens na lista
# Inicio Item 407
# Fim Item 407
# Duração : 2.906918525695801 segundos
# Faltam 3244 itens na lista
# Inicio Item 408
# Fim Item 408
# Duração : 2.7057902812957764 segundos
# Faltam 3243 itens na lista
# Inicio Item 409
# Faltam 2664 itens na lista
# Inicio Item 988
# Fim Item 988
# Duração : 10.706094980239868 segundos
# Faltam 2663 itens na lista
# Inicio Item 989
# Fim Item 989
# Duração : 10.706031560897827 segundos
# Faltam 2662 itens na lista
# Inicio Item 990
# Fim Item 990
# Duração : 18.441887378692627 segundos
# Faltam 2661 itens na lista
# Inicio Item 991
# Fim Item 991
# Duração : 15.133297204971313 segundos
# Faltam 2660 itens na lista
# Inicio Item 992
# Fim Item 992
# Duração : 16.110050678253174 segundos
# Faltam 2659 itens na lista
# Inicio Item 993
# Fim Item 993
# Duração : 24.016117572784424 segundos
# Faltam 2658 itens na lista
# Inicio Item 994
# Fim Item 994
# Duração : 21.53520154953003 segundos
# Faltam 2657 itens na lista
# Inicio Item 995
# Fim Item 995
# Duração : 20.14347505569458 segundos
# Faltam 2656 itens na lista
# Inicio Item 996
# Fim Item 996
# Duração : 19.45513129234314 segundos
# Faltam 2655 itens na lista
# Inicio Item 997
# Fim Item 997
# Duração : 13.465349912643433 segundos
# Faltam 2654 itens na lista
# Inicio Item 998
# Fim Item 998
# Duração : 11.641204357147217 segundos
# Faltam 2653 itens na lista
# Inicio Item 999
# Fim Item 999
# Duração : 12.317100286483765 segundos

# %%
# Como a base de dados ficou muito grande, este comando e o seguinte devem ser rodados separadamente
# com limpeza de memória entre eles

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='teste_dengue')

clima = pd.DataFrame()


for i in dadosclima:
    if 1000 <= dadosclima.index(i) < 2000:
        
 
        
        print('Faltam ' + str(len(dadosclima) - dadosclima.index(i) +1) +' itens na lista' )
        print('Inicio Item ' + str(dadosclima.index(i)))
        inicio = time.time()
        base1 = pd.read_csv(i, delimiter = ';',engine = 'python', nrows = 3)
        base2 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 3, nrows = 4)
        estado = base1.iloc[0,1]
        estacao = base1.iloc[1,1]
        lat = str(base2.iloc[0,1]).replace(',','.')
        long = str(base2.iloc[1,1]).replace(',','.')
        
        # Tratando casos onde temos latitude que começa apenas com . ou , (positivos e negativos)
        
        if lat[0] == '.':
            lat = str(0)+lat
        elif lat[0] == '-':
            lat = '-' + str(0) + lat[1:]
        else:
            pass
        if long[0] == '.':
            long = str(0)+long
        elif long[0] == '-':
            long = '-'+ str(0) + long [1:]                
        else: 
            pass
        
        # Passa as coordenadas 
        
        location = geolocator.reverse(lat +', ' + long)
        
         
        try:
            cidade = location.raw['address']['city'] 

        except:
            cidade = 'Erro'
            
        try:
            cep = location.raw['address']['postcode'] 
        except:
            cep = 'Erro'
        
        
        # Pega o restante da base, e adiciona colunas com os valores que descobrimos anteriormente
        
        base3 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 8)
        base3['estacao'] = estacao
        base3['estado'] = estado
        base3['cidade'] = pd.Series()
        base3['cep'] = pd.Series()
        base3['lat'] = lat
        base3['long'] = long
        
        
        try:
            base3['cidade'] = cidade

        except:
            pass
        
        try:
            base3['cep'] = cep
        except:
            pass
        
        
        
        clima = clima.append(base3)
        fim = time.time()
        tempo = fim - inicio

        print('Fim Item ' + str(dadosclima.index(i)))
        print('Duração : ' + str(tempo) + ' segundos')
        

    else:
        pass

    
clima.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part2.csv')
del clima
# Out:
# Faltam 2652 itens na lista
# Inicio Item 1000
# Fim Item 1000
# Duração : 6.17300009727478 segundos
# Faltam 2651 itens na lista
# Inicio Item 1001
# Fim Item 1001
# Duração : 0.5350117683410645 segundos
# Faltam 2650 itens na lista
# Inicio Item 1002
# Fim Item 1002
# Duração : 0.4682645797729492 segundos
# Faltam 2649 itens na lista
# Inicio Item 1003
# Fim Item 1003
# Duração : 0.5301086902618408 segundos
# Faltam 2648 itens na lista
# Inicio Item 1004
# Fim Item 1004
# Duração : 0.5056962966918945 segundos
# Faltam 2647 itens na lista
# Inicio Item 1005
# Fim Item 1005
# Duração : 0.9859597682952881 segundos
# Faltam 2646 itens na lista
# Inicio Item 1006
# Fim Item 1006
# Duração : 1.0950119495391846 segundos
# Faltam 2645 itens na lista
# Inicio Item 1007
# Fim Item 1007
# Duração : 0.495516300201416 segundos
# Faltam 2644 itens na lista
# Inicio Item 1008
# Fim Item 1008
# Duração : 0.4964733123779297 segundos
# Faltam 2643 itens na lista
# Inicio Item 1009
# Fim Item 1009
# Duração : 0.831923246383667 segundos
# Faltam 2642 itens na lista
# Inicio Item 1010
# Fim Item 1010
# Duração : 3.3171229362487793 segundos
# Faltam 2641 itens na lista
# Inicio Item 1011
# Fim Item 1011
# Duração : 0.5921404361724854 segundos
# Faltam 2640 itens na lista
# Inicio Item 1012
# Fim Item 1012
# Duração : 0.5991659164428711 segundos
# Faltam 2639 itens na lista
# Inicio Item 1013
# Fim Item 1013
# Duração : 1.0576221942901611 segundos
# Faltam 2638 itens na lista
# Inicio Item 1014
# Fim Item 1014
# Duração : 0.5700492858886719 segundos
# Faltam 2637 itens na lista
# Inicio Item 1015
# Fim Item 1015
# Duração : 1.7202210426330566 segundos
# Faltam 2636 itens na lista
# Inicio Item 1016
# Fim Item 1016
# Duração : 0.5688972473144531 segundos
# Faltam 2635 itens na lista
# Inicio Item 1017
# Fim Item 1017
# Duração : 5.490840196609497 segundos
# Faltam 2634 itens na lista
# Inicio Item 1018
# Fim Item 1018
# Duração : 0.672130823135376 segundos
# Faltam 2633 itens na lista
# Inicio Item 1019
# Fim Item 1019
# Duração : 0.5819272994995117 segundos
# Faltam 2632 itens na lista
# Inicio Item 1020
# Fim Item 1020
# Duração : 0.5893793106079102 segundos
# Faltam 2631 itens na lista
# Inicio Item 1021
# Fim Item 1021
# Duração : 0.5926699638366699 segundos
# Faltam 2630 itens na lista
# Inicio Item 1022
# Fim Item 1022
# Duração : 0.6710882186889648 segundos
# Faltam 2629 itens na lista
# Inicio Item 1023
# Fim Item 1023
# Duração : 1.253972053527832 segundos
# Faltam 2628 itens na lista
# Inicio Item 1024
# Fim Item 1024
# Duração : 1.2858614921569824 segundos
# Faltam 2627 itens na lista
# Inicio Item 1025
# Fim Item 1025
# Duração : 0.689490556716919 segundos
# Faltam 2626 itens na lista
# Inicio Item 1026
# Fim Item 1026
# Duração : 0.7034409046173096 segundos
# Faltam 2625 itens na lista
# Inicio Item 1027
# Fim Item 1027
# Duração : 0.646528959274292 segundos
# Faltam 2624 itens na lista
# Inicio Item 1028
# Fim Item 1028
# Duração : 0.6399459838867188 segundos
# Faltam 2623 itens na lista
# Inicio Item 1029
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1906         result = _lib.SSL_do_handshake(self._ssl)
# -> 1907         self._raise_ssl_error(self._ssl, result)
#    1908
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
# --> 456                     raise timeout('select timed out')
#     457                 continue
#
# timeout: select timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
# --> 346             self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#     347             raise
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     305         if isinstance(err, SocketTimeout):
# --> 306             raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#     307
#
# ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     666                                 release_conn=release_conn, body_pos=body_pos,
# --> 667                                 **response_kw)
#     668
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=-2.08499999&lon=-60.04888888&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\geopy\adapters.py in _request(self, url, timeout, headers)
#     382         try:
# --> 383             resp = self.session.get(url, timeout=timeout, headers=headers)
#     384         except Exception as error:
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=-2.08499999&lon=-60.04888888&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# <ipython-input-5-33f2e247f14b> in <module>
#      40         # Passa as coordenadas
#      41
# ---> 42         location = geolocator.reverse(lat +', ' + long)
#      43
#      44
#
# ~\Anaconda3\lib\site-packages\geopy\geocoders\nominatim.py in reverse(self, query, exactly_one, timeout, language, addressdetails, zoom)
#     357         logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     358         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 359         return self._call_geocoder(url, callback, timeout=timeout)
#     360
#     361     def _parse_code(self, place):
#
# ~\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     358         try:
#     359             if is_json:
# --> 360                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     361             else:
#     362                 result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# ~\Anaconda3\lib\site-packages\geopy\adapters.py in get_json(self, url, timeout, headers)
#     371
#     372     def get_json(self, url, *, timeout, headers):
# --> 373         resp = self._request(url, timeout=timeout, headers=headers)
#     374         try:
#     375             return resp.json()
#
# ~\Anaconda3\lib\site-packages\geopy\adapters.py in _request(self, url, timeout, headers)
#     393                     raise GeocoderServiceError(message)
#     394                 else:
# --> 395                     raise GeocoderUnavailable(message)
#     396             elif isinstance(error, requests.Timeout):
#     397                 raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=-2.08499999&lon=-60.04888888&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))

# %%
# Como a base de dados ficou muito grande, este comando e o seguinte devem ser rodados separadamente
# com limpeza de memória entre eles

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='teste_dengue')

clima = pd.DataFrame()


for i in dadosclima:
    if 2000 <=dadosclima.index(i) < 3000:
        
 
        
        print('Faltam ' + str(len(dadosclima) - dadosclima.index(i) +1) +' itens na lista' )
        print('Inicio Item ' + str(dadosclima.index(i)))
        inicio = time.time()
        base1 = pd.read_csv(i, delimiter = ';',engine = 'python', nrows = 3)
        base2 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 3, nrows = 4)
        estado = base1.iloc[0,1]
        estacao = base1.iloc[1,1]
        lat = str(base2.iloc[0,1]).replace(',','.')
        long = str(base2.iloc[1,1]).replace(',','.')
        
        # Tratando casos onde temos latitude que começa apenas com . ou , (positivos e negativos)
        
        if lat[0] == '.':
            lat = str(0)+lat
        elif lat[0] == '-':
            lat = '-' + str(0) + lat[1:]
        else:
            pass
        if long[0] == '.':
            long = str(0)+long
        elif long[0] == '-':
            long = '-'+ str(0) + long [1:]                
        else: 
            pass
        
        # Passa as coordenadas 
        
        location = geolocator.reverse(lat +', ' + long)
        
        
        try:
            cidade = location.raw['address']['city'] 

        except:
            cidade = 'Erro'
            
        try:
            cep = location.raw['address']['postcode'] 
        except:
            cep = 'Erro'
        
        # Pega o restante da base, e adiciona colunas com os valores que descobrimos anteriormente
        
        base3 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 8)
        base3['estacao'] = estacao
        base3['estado'] = estado
        base3['cidade'] = pd.Series()
        base3['cep'] = pd.Series()
        base3['lat'] = lat
        base3['long'] = long
        
        
        try:
            base3['cidade'] = cidade

        except:
            pass
        
        try:
            base3['cep'] = cep
        except:
            pass
        
        
        
        
        clima = clima.append(base3)
        fim = time.time()
        tempo = fim - inicio

        print('Fim Item ' + str(dadosclima.index(i)))
        print('Duração : ' + str(tempo) + ' segundos')
        

    else:
        pass

    
clima.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part3.csv')
del clima

# %%
# Como a base de dados ficou muito grande, este comando e o seguinte devem ser rodados separadamente
# com limpeza de memória entre eles

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='teste_dengue')

clima = pd.DataFrame()


for i in dadosclima:
    if dadosclima.index(i) >= 3000:
        
 
        
        print('Faltam ' + str(len(dadosclima) - dadosclima.index(i) +1) +' itens na lista' )
        print('Inicio Item ' + str(dadosclima.index(i)))
        inicio = time.time()
        base1 = pd.read_csv(i, delimiter = ';',engine = 'python', nrows = 3)
        base2 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 3, nrows = 4)
        estado = base1.iloc[0,1]
        estacao = base1.iloc[1,1]
        lat = str(base2.iloc[0,1]).replace(',','.')
        long = str(base2.iloc[1,1]).replace(',','.')
        
        # Tratando casos onde temos latitude que começa apenas com . ou , (positivos e negativos)
        
        if lat[0] == '.':
            lat = str(0)+lat
        elif lat[0] == '-':
            lat = '-' + str(0) + lat[1:]
        else:
            pass
        if long[0] == '.':
            long = str(0)+long
        elif long[0] == '-':
            long = '-'+ str(0) + long [1:]                
        else: 
            pass
        
        # Passa as coordenadas 
        
        location = geolocator.reverse(lat +', ' + long)
        
        
         
        try:
            cidade = location.raw['address']['city'] 

        except:
            cidade = 'Erro'
            
        try:
            cep = location.raw['address']['postcode'] 
        except:
            cep = 'Erro'
        
        
        # Pega o restante da base, e adiciona colunas com os valores que descobrimos anteriormente
        
        base3 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 8)
        base3['estacao'] = estacao
        base3['estado'] = estado
        base3['cidade'] = pd.Series()
        base3['cep'] = pd.Series()
        base3['lat'] = lat
        base3['long'] = long
        
        
        try:
            base3['cidade'] = cidade

        except:
            pass
        
        try:
            base3['cep'] = cep
        except:
            pass
        
        
        
        clima = clima.append(base3)
        fim = time.time()
        tempo = fim - inicio

        print('Fim Item ' + str(dadosclima.index(i)))
        print('Duração : ' + str(tempo) + ' segundos')
        

    else:
        pass
    
clima.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part4.csv')
del clima

# %% [markdown]
# ### Carregando agora a base de casos de dengue
# ### Vamos seguir a estratégia: Com os dados de Dengue, tentar cruzar os dados com as bases de clima individualmente, para evitar de termos que consolidar uma base completa de clima que ficaria muito grande em memória.
#
# ### As cidades e Estados onde não conseguirmos dados de dengue x clima, iremos retirar da análise e assim faremos o filtro para tentar reduzir um pouco os dados possibilitando uso da memória para consolidar uma abt

# %%
#Primeiro pegando uma lista com todos os arquivos na pasta onde estão os dados

dadosdengue = []

import sys

root = r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue\DadosAnuaisCSV'
      
            
for root, dirs, files in os.walk(root):
     for file in files:
        dadosdengue.append(os.path.join(root, file))

# %%
#Casos de Dengue

#Criando um DataFrame

dengue = pd.DataFrame()


for i in dadosdengue:
    print(i)
    inicio = time.time()
    base1 = pd.read_csv(i, engine = 'python')
    dengue = dengue.append(base1, sort = False)
    fim = time.time()
    duracao = fim - inicio
    print(duracao)
    
dengue.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//dengue.csv')

# %%
dengue = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//dengue.csv')

# %%
notific_dengue = dengue[['DT_NOTIFIC','ID_MUNICIP','NU_ANO','NU_NOTIFIC']].groupby(['DT_NOTIFIC','NU_ANO','ID_MUNICIP']).agg('count').reset_index()

# %%
# Vamos usar o campo ID_MUNICIP posteriormente para fazer um join e descobrir o nome da cidade.
# Vamos transformar o campo em string para não termos problemas no join

notific_dengue['ID_MUNICIP'] = notific_dengue.ID_MUNICIP.apply(lambda x: str(x))

# %%
notific_dengue.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//notific_dengue.csv')

# %%
del dengue

# %% [markdown]
# ### Lendo agora a base de cidades
# ### Usaremos a base de cidades para identificar as cidades onde tivemos casos de dengue, para depois cruzar através da cidade os casos com os dados de clima

# %%
cidades = pd.read_excel(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Cidades//RELATORIO_DTB_BRASIL_DISTRITO.xls')

# %%
# Em uma das bases temos o código do município com 7 dígitos e em outra com 6, vamos igualar

cidades['ID_MUNICIP'] = cidades['Código Município Completo'].apply(lambda x: str(x)[:-1])

# %%
dengue_cidades = pd.merge(notific_dengue,cidades,how='inner',on='ID_MUNICIP')

# %%
# Deletando as bases anteriores para liberar memória

del cidades

# %%
dengue_cidades.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//denguecidades.csv')

# %% [markdown]
# # -------------------------------------------------
#
# # 3 . Tratando a base inicial de dados
#
# # --------------------------------------------------
#
#
#
#
# ### Temos todas as bases de dados que precisamos agora. Precisamos agregar e fazer join para começar a atacar o problema.
#
# ### Temos a base de clima com dados de hora em hora de todas as estações de medição espalhadas pelo Brasil
# ### Temos a base de número de notificações de dengue em cada cidade
#
# ### Para cruzar estas duas bases a chave será o nome da cidade e data
#
# ### A estratégia será verificar quantos cruzamentos temos de dados de clima x dengue para começar a análise

# %%
dengue_cidades = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//denguecidades.csv')

# %%
dengue_cidades = dengue_cidades[['DT_NOTIFIC','ID_MUNICIP','NU_ANO','Nome_UF','Nome_Município','NU_NOTIFIC']]
dengue_cidades = dengue_cidades.drop_duplicates(subset = ['DT_NOTIFIC','ID_MUNICIP'])

# %%
states = {
    'AC': 'Acre',
    'AL': 'Alagoas',
    'AP': 'Amapá',
    'AM': 'Amazonas',
    'BA': 'Bahia',
    'CE': 'Ceará',
    'DF': 'Distrito Federal',
    'ES': 'Espírito Santo',
    'GO': 'Goiás',
    'MA': 'Maranhão',
    'MT': 'Mato Grosso',
    'MS': 'Mato Grosso do Sul',
    'MG': 'Minas Gerais',
    'PA': 'Pará',
    'PB': 'Paraíba',
    'PR': 'Paraná',
    'PE': 'Pernambuco',
    'PI': 'Piauí',
    'RJ': 'Rio de Janeiro',
    'RN': 'Rio Grande do Norte',
    'RS': 'Rio Grande do Sul',
    'RO': 'Rondônia',
    'RR': 'Roraima',
    'SC': 'Santa Catarina',
    'SP': 'São Paulo',
    'SE': 'Sergipe',
    'TO': 'Tocantins'
}

states = {v: k for k, v in states.items()}

# %%
dengue_cidades['UF'] = dengue_cidades['Nome_UF'].map(states)

# %% [markdown]
# ### Começando com as bases de clima

# %%
# Tratando os dados das bases.
# Começando pelo clima 1

clima1 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part1.csv')

# %%
# Como temos colunas com tipos diferentes de dados, vamos detectar o que está com tipos diferentes para poder tratar

for i in clima1.columns:
    print(clima1[i].apply(type).value_counts())

# %%
# Temos muitos dados sendo lidos como string, provavelmente por conta da virgula em campos numericos. 
# Vamos começar ajustando esse ponto
# Esta parte vai transformar colunas que são inteiras string para valores numéricos



for i in clima1.iloc[:,3:20].columns:
    
    
    print(i)
    clima1[i] = [float(x.replace(',','.')) if isinstance(x, str) else float(x) for x in clima1[i]]

    
# cidade e cep precisamos transformar para string

clima1.cidade = clima1.cidade.apply(lambda x: str(x))
clima1.cep = clima1.cep.apply(lambda x: str(x))


# for i in clima1.iloc[:,3:20].columns:
#     print(i)
#     print(type(clima1[i][0]))
#     if isinstance(clima1[i][0], str) == True:        
#         clima1[i] = clima1[i].apply(lambda x: float(x.replace(',','.')))
#         print(type(clima1[i][0]))
#     else: 
#         pass

# %%
# Vamos verificar se o tratamento foi efetivo

for i in clima1.columns:
    print(clima1[i].apply(type).value_counts())

# %%
# Agora que todos os valores estão devidamente tratados, vamos reduzir a base para facilitar o trabalho em memória
# Vamos reduzir a base a valores diários e não mais horários.

# Como o efeito da dengue será visto em dias, não há necessidade a princípio de termos dados de clima de hora em hora
# A tentativa será feita em cima de médias diárias


clima1_reduzida = clima1.groupby(['DATA (YYYY-MM-DD)','estado','cidade','cep','lat','long']).agg('mean').reset_index()
abt1 = pd.merge(clima1_reduzida,dengue_cidades, how = 'inner', left_on = ['DATA (YYYY-MM-DD)','estado','cidade'], right_on = ['DT_NOTIFIC','UF','Nome_Município'])

# %%
abt1.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt1.csv')

# %%
del clima1
del clima1_reduzida
del abt1

# %% [markdown]
# ### Vamos executar a mesma estratégia para as bases de clima 2, 3 e 4

# %% [markdown]
# ### Clima 2

# %%
# Tratando a base clima 2

clima2 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part2.csv')

# %%
# Como temos colunas com tipos diferentes de dados, vamos detectar o que está com tipos diferentes para poder tratar

for i in clima2.columns:
    print(clima2[i].apply(type).value_counts())

# %%
for i in clima2.iloc[:,3:20].columns:
    
    
    print(i)
    clima2[i] = [float(x.replace(',','.')) if isinstance(x, str) else float(x) for x in clima2[i]]
    
    
    
#     print(i)
#     print(type(clima2[i][0]))
#     if isinstance(clima2[i][0], str) == True:        
#         clima2[i] = clima2[i].apply(lambda x: float(x.replace(',','.')))
#         print(type(clima2[i][0]))
#     else: 
#         pass

# %%
# cidade e cep precisamos transformar para string

clima2.cidade = clima2.cidade.apply(lambda x: str(x))
clima2.cep = clima2.cep.apply(lambda x: str(x))

# %%
# Chegando se o tratamento foi efetivo

for i in clima2.columns:
    print(clima2[i].apply(type).value_counts())

# %%
# Agora que todos os valores estão devidamente tratados, vamos reduzir a base para facilitar o trabalho em memória
# Vamos reduzir a base a valores diários e não mais horários.

# Como o efeito da dengue será visto em dias, não há necessidade a princípio de termos dados de clima de hora em hora
# A tentativa será feita em cima de médias diárias


clima2_reduzida = clima2.groupby(['DATA (YYYY-MM-DD)','estado','cidade','cep','lat','long']).agg('mean').reset_index()
abt2 = pd.merge(clima2_reduzida,dengue_cidades, how = 'inner', left_on = ['DATA (YYYY-MM-DD)','estado','cidade'], right_on = ['DT_NOTIFIC','UF','Nome_Município'])

# %%
abt2.count()

# %%
abt2.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt2.csv')

# %%
del clima2
del clima2_reduzida
del abt2

# %% [markdown]
# ### Clima 3

# %%
# Agora para a base clima 3
# A partir da base clima 3, o INMET adiciona uma outra coluna de data diferente. No meio da base temos essa mudança no schema
# Teremos que tratar isso transformando tudo em uma coluna unica de data 

clima3 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part3.csv')

# %%
clima3.Data = clima3.Data.apply(lambda x: str(x))

clima3_part1 = clima3[clima3['DATA (YYYY-MM-DD)'].notnull()]
clima3_part2 = clima3[clima3['DATA (YYYY-MM-DD)'].isnull()]

# %%
# Tratando a coluna de Data

def ajuste_data(x : str):    
    return(x[:4]+'-'+x[5:7]+'-'+x[8:10])

# --------------------------------------------------

    
clima3_part2['DATA (YYYY-MM-DD)'] = clima3_part2.Data.apply(lambda x: ajuste_data(x))

clima3 = pd.concat([clima3_part1,clima3_part2], sort= False)

# %%
clima3 = clima3.drop('Data', axis = 1)
clima3 = clima3.drop('Hora UTC', axis = 1)

del clima3_part1
del clima3_part2

# %%
for i in clima3.iloc[:,3:21].columns:
    
    
    print(i)
    clima3[i] = [float(x.replace(',','.')) if isinstance(x, str) else float(x) for x in clima3[i]]
    
    
# cidade e cep precisamos transformar para string

clima3.cidade = clima3.cidade.apply(lambda x: str(x))
clima3.cep = clima3.cep.apply(lambda x: str(x))

# %%
# Chegando se o tratamento foi efetivo

for i in clima3.columns:
    print(clima3[i].apply(type).value_counts())

# %%
# Agora que todos os valores estão devidamente tratados, vamos reduzir a base para facilitar o trabalho em memória
# Vamos reduzir a base a valores diários e não mais horários.

# Como o efeito da dengue será visto em dias, não há necessidade a princípio de termos dados de clima de hora em hora
# A tentativa será feita em cima de médias diárias


clima3_reduzida = clima3.groupby(['DATA (YYYY-MM-DD)','estado','cidade','cep','lat','long']).agg('mean').reset_index()
abt3 = pd.merge(clima3_reduzida,dengue_cidades, how = 'inner', left_on = ['DATA (YYYY-MM-DD)','estado','cidade'], right_on = ['DT_NOTIFIC','UF','Nome_Município'])

# %%
abt3.count()

# %%
abt3.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt3.csv')

# %%
del clima3
del clima3_reduzida
del abt3

# %% [markdown]
# ### Clima 4

# %%
# Agora para a base clima 4

clima4 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part4.csv')

# %%
# Tratando a coluna de Data

def ajuste_data(x : str):    
    return(x[:4]+'-'+x[5:7]+'-'+x[8:10])

# --------------------------------------------------

    
clima4.Data = clima4.Data.apply(lambda x: ajuste_data(x))
clima4 = clima4.rename(columns={'Data': 'DATA (YYYY-MM-DD)'})

# %%
for i in clima4.iloc[:,3:21].columns:
    
    
    print(i)
    clima4[i] = [float(x.replace(',','.')) if isinstance(x, str) else float(x) for x in clima4[i]]
    
    
# cidade e cep precisamos transformar para string

clima4.cidade = clima4.cidade.apply(lambda x: str(x))
clima4.cep = clima4.cep.apply(lambda x: str(x))

# %%
# Chegando se o tratamento foi efetivo

for i in clima4.columns:
    print(clima4[i].apply(type).value_counts())

# %%
# Agora que todos os valores estão devidamente tratados, vamos reduzir a base para facilitar o trabalho em memória
# Vamos reduzir a base a valores diários e não mais horários.

# Como o efeito da dengue será visto em dias, não há necessidade a princípio de termos dados de clima de hora em hora
# A tentativa será feita em cima de médias diárias


clima4_reduzida = clima4.groupby(['DATA (YYYY-MM-DD)','estado','cidade','cep','lat','long']).agg('mean').reset_index()
abt4 = pd.merge(clima4_reduzida,dengue_cidades, how = 'inner', left_on = ['DATA (YYYY-MM-DD)','estado','cidade'], right_on = ['DT_NOTIFIC','UF','Nome_Município'])

# %%
abt4.count()

# %%
abt4.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt4.csv')

# %% [markdown]
# # -----------------------------------------------------------

# %% [markdown]
# ### Finalizando a ABT empilhando os dados
#
# ### Até então o que poderíamos tirar de informação das bases foi retirado. O Refinamento da informação será feito no próximo notebook antes da análise exploratória

# %%
abt1 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt1.csv')
abt2 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt2.csv')
abt3 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt3.csv')
abt4 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt4.csv')

# %%
abt1.columns

# %%
abt2.columns

# %%
abt3.columns

# %%
abt4.columns

# %%
abt_final = pd.concat([abt1,abt2], sort=False)

# %%
abt3 = abt3[['Unnamed: 0', 'DATA (YYYY-MM-DD)', 'estado', 'cidade', 'cep', 'lat',
       'long', 'Unnamed: 0.1', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (W/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)', 'Unnamed: 19', 'DT_NOTIFIC',
       'ID_MUNICIP', 'NU_ANO', 'Nome_UF', 'Nome_Município', 'NU_NOTIFIC']]

# %%
abt4 = abt4[['Unnamed: 0', 'DATA (YYYY-MM-DD)', 'estado', 'cidade', 'cep', 'lat',
       'long', 'Unnamed: 0.1', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (W/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)', 'Unnamed: 19', 'DT_NOTIFIC',
       'ID_MUNICIP', 'NU_ANO', 'Nome_UF', 'Nome_Município', 'NU_NOTIFIC']]

# %%
abt_final = pd.concat([abt_final,abt3,abt4], sort = False)

# %%
abt_final.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt_final.csv')
