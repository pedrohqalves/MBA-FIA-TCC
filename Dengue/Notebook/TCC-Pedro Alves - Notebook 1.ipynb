# %%
# !pip install geopy

# %% [markdown]
# # ===============================
#
#
# # 1 . Importando as bibliotecas básicas
#
#
# # ===============================

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time

# %% [markdown]
# # ==============================
#
#
# # 2. Lendo as bases de dados
#
#
# # ==============================

# %% [markdown]
# ### Primeiro lendo as bases de Clima
#
# ### No caso destas bases, temos o nome da estação, que pode ou não ser o mesmo nome da cidade que ela está localizada. Para facilitar posteriormente cruzarmos cidade a cidade com os casos de dengue, vamos usar os dados de latitude e longitude para descobrir a cidade onde está localizada a estação
#
# ### Vamos acrescentar uma coluna em cada base de cada estação mostrando cidade, estado e cep (que pode facilitar depois a localização também)

# %% [markdown]
# ## ----------------------------------------------
#
#
# ### Para cada base vamos ler o cabeçalho, retirar os dados de localização, acrescentar como colunas na base, e guardar os dados para serem empilhados com os da próxima base, e assim por diante

# %%
#Primeiro pegando uma lista com todos os arquivos na pasta onde estão os dados

dadosclima = []

import sys

root = r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima\Bases Anuais'
      
            
for root, dirs, files in os.walk(root):
     for file in files:
        dadosclima.append(os.path.join(root, file))

# %%
# Como a base de dados ficou muito grande, este comando e o seguinte devem ser rodados separadamente
# com limpeza de memória entre eles

#Importa a lib para descobrir localização através de coordenadas

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='teste_dengue')

clima = pd.DataFrame()


for i in dadosclima:
    if dadosclima.index(i) < 1000:
        
        
        
        print('Faltam ' + str(len(dadosclima) - dadosclima.index(i) +1) +' itens na lista' )
        print('Inicio Item ' + str(dadosclima.index(i)))
        inicio = time.time()
        base1 = pd.read_csv(i, delimiter = ';',engine = 'python', nrows = 3)
        base2 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 3, nrows = 4)
        estado = base1.iloc[0,1]
        estacao = base1.iloc[1,1]
        lat = str(base2.iloc[0,1]).replace(',','.')
        long = str(base2.iloc[1,1]).replace(',','.')
        
        # Tratando casos onde temos latitude que começa apenas com . ou , (positivos e negativos)
        
        if lat[0] == '.':
            lat = str(0)+lat
        elif lat[0] == '-':
            lat = '-' + str(0) + lat[1:]
        else:
            pass
        if long[0] == '.':
            long = str(0)+long
        elif long[0] == '-':
            long = '-'+ str(0) + long [1:]                
        else: 
            pass
        
        # Passa as coordenadas 
        
        location = geolocator.reverse(lat +', ' + long)
        
        
        try:
            cidade = location.raw['address']['city'] 

        except:
            cidade = 'Erro'
            
        try:
            cep = location.raw['address']['postcode'] 
        except:
            cep = 'Erro'
        
        # Pega o restante da base, e adiciona colunas com os valores que descobrimos anteriormente
        
        base3 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 8)
        base3['estacao'] = estacao
        base3['estado'] = estado
        base3['cidade'] = pd.Series()
        base3['cep'] = pd.Series()
        base3['lat'] = lat
        base3['long'] = long
        
        
        try:
            base3['cidade'] = cidade

        except:
            pass
        
        try:
            base3['cep'] = cep
        except:
            pass
        
        
        
        clima = clima.append(base3)
        fim = time.time()
        tempo = fim - inicio

        print('Fim Item ' + str(dadosclima.index(i)))
        print('Duração : ' + str(tempo) + ' segundos')
        

    else:
        pass
    


clima.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part1.csv')
del clima

# %%
# Como a base de dados ficou muito grande, este comando e o seguinte devem ser rodados separadamente
# com limpeza de memória entre eles

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='teste_dengue')

clima = pd.DataFrame()


for i in dadosclima:
    if 1000 <= dadosclima.index(i) < 2000:
        
 
        
        print('Faltam ' + str(len(dadosclima) - dadosclima.index(i) +1) +' itens na lista' )
        print('Inicio Item ' + str(dadosclima.index(i)))
        inicio = time.time()
        base1 = pd.read_csv(i, delimiter = ';',engine = 'python', nrows = 3)
        base2 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 3, nrows = 4)
        estado = base1.iloc[0,1]
        estacao = base1.iloc[1,1]
        lat = str(base2.iloc[0,1]).replace(',','.')
        long = str(base2.iloc[1,1]).replace(',','.')
        
        # Tratando casos onde temos latitude que começa apenas com . ou , (positivos e negativos)
        
        if lat[0] == '.':
            lat = str(0)+lat
        elif lat[0] == '-':
            lat = '-' + str(0) + lat[1:]
        else:
            pass
        if long[0] == '.':
            long = str(0)+long
        elif long[0] == '-':
            long = '-'+ str(0) + long [1:]                
        else: 
            pass
        
        # Passa as coordenadas 
        
        location = geolocator.reverse(lat +', ' + long)
        
         
        try:
            cidade = location.raw['address']['city'] 

        except:
            cidade = 'Erro'
            
        try:
            cep = location.raw['address']['postcode'] 
        except:
            cep = 'Erro'
        
        
        # Pega o restante da base, e adiciona colunas com os valores que descobrimos anteriormente
        
        base3 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 8)
        base3['estacao'] = estacao
        base3['estado'] = estado
        base3['cidade'] = pd.Series()
        base3['cep'] = pd.Series()
        base3['lat'] = lat
        base3['long'] = long
        
        
        try:
            base3['cidade'] = cidade

        except:
            pass
        
        try:
            base3['cep'] = cep
        except:
            pass
        
        
        
        clima = clima.append(base3)
        fim = time.time()
        tempo = fim - inicio

        print('Fim Item ' + str(dadosclima.index(i)))
        print('Duração : ' + str(tempo) + ' segundos')
        

    else:
        pass

    
clima.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part2.csv')
del clima

# %%
# Como a base de dados ficou muito grande, este comando e o seguinte devem ser rodados separadamente
# com limpeza de memória entre eles

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='teste_dengue')

clima = pd.DataFrame()


for i in dadosclima:
    if 2000 <=dadosclima.index(i) < 3000:
        
 
        
        print('Faltam ' + str(len(dadosclima) - dadosclima.index(i) +1) +' itens na lista' )
        print('Inicio Item ' + str(dadosclima.index(i)))
        inicio = time.time()
        base1 = pd.read_csv(i, delimiter = ';',engine = 'python', nrows = 3)
        base2 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 3, nrows = 4)
        estado = base1.iloc[0,1]
        estacao = base1.iloc[1,1]
        lat = str(base2.iloc[0,1]).replace(',','.')
        long = str(base2.iloc[1,1]).replace(',','.')
        
        # Tratando casos onde temos latitude que começa apenas com . ou , (positivos e negativos)
        
        if lat[0] == '.':
            lat = str(0)+lat
        elif lat[0] == '-':
            lat = '-' + str(0) + lat[1:]
        else:
            pass
        if long[0] == '.':
            long = str(0)+long
        elif long[0] == '-':
            long = '-'+ str(0) + long [1:]                
        else: 
            pass
        
        # Passa as coordenadas 
        
        location = geolocator.reverse(lat +', ' + long)
        
        
        try:
            cidade = location.raw['address']['city'] 

        except:
            cidade = 'Erro'
            
        try:
            cep = location.raw['address']['postcode'] 
        except:
            cep = 'Erro'
        
        # Pega o restante da base, e adiciona colunas com os valores que descobrimos anteriormente
        
        base3 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 8)
        base3['estacao'] = estacao
        base3['estado'] = estado
        base3['cidade'] = pd.Series()
        base3['cep'] = pd.Series()
        base3['lat'] = lat
        base3['long'] = long
        
        
        try:
            base3['cidade'] = cidade

        except:
            pass
        
        try:
            base3['cep'] = cep
        except:
            pass
        
        
        
        
        clima = clima.append(base3)
        fim = time.time()
        tempo = fim - inicio

        print('Fim Item ' + str(dadosclima.index(i)))
        print('Duração : ' + str(tempo) + ' segundos')
        

    else:
        pass

    
clima.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part3.csv')
del clima
# Out:
# Faltam 1825 itens na lista
# Inicio Item 2000
# Fim Item 2000
# Duração : 1.5597944259643555 segundos
# Faltam 1824 itens na lista
# Inicio Item 2001
# Fim Item 2001
# Duração : 0.5171463489532471 segundos
# Faltam 1823 itens na lista
# Inicio Item 2002
# Fim Item 2002
# Duração : 0.5085515975952148 segundos
# Faltam 1822 itens na lista
# Inicio Item 2003
# Fim Item 2003
# Duração : 0.5221920013427734 segundos
# Faltam 1821 itens na lista
# Inicio Item 2004
# Fim Item 2004
# Duração : 0.5447795391082764 segundos
# Faltam 1820 itens na lista
# Inicio Item 2005
# Fim Item 2005
# Duração : 0.4826788902282715 segundos
# Faltam 1819 itens na lista
# Inicio Item 2006
# Fim Item 2006
# Duração : 0.49965906143188477 segundos
# Faltam 1818 itens na lista
# Inicio Item 2007
# Fim Item 2007
# Duração : 0.4880855083465576 segundos
# Faltam 1817 itens na lista
# Inicio Item 2008
# Fim Item 2008
# Duração : 0.5468864440917969 segundos
# Faltam 1816 itens na lista
# Inicio Item 2009
# Fim Item 2009
# Duração : 0.457103967666626 segundos
# Faltam 1815 itens na lista
# Inicio Item 2010
# Fim Item 2010
# Duração : 0.5056891441345215 segundos
# Faltam 1814 itens na lista
# Inicio Item 2011
# Fim Item 2011
# Duração : 0.53305983543396 segundos
# Faltam 1813 itens na lista
# Inicio Item 2012
# Fim Item 2012
# Duração : 0.5192279815673828 segundos
# Faltam 1812 itens na lista
# Inicio Item 2013
# Fim Item 2013
# Duração : 0.5962142944335938 segundos
# Faltam 1811 itens na lista
# Inicio Item 2014
# Fim Item 2014
# Duração : 0.531825065612793 segundos
# Faltam 1810 itens na lista
# Inicio Item 2015
# Fim Item 2015
# Duração : 0.8954761028289795 segundos
# Faltam 1809 itens na lista
# Inicio Item 2016
# Fim Item 2016
# Duração : 0.5499267578125 segundos
# Faltam 1808 itens na lista
# Inicio Item 2017
# Fim Item 2017
# Duração : 0.5414073467254639 segundos
# Faltam 1807 itens na lista
# Inicio Item 2018
# Fim Item 2018
# Duração : 0.5238907337188721 segundos
# Faltam 1806 itens na lista
# Inicio Item 2019
# Fim Item 2019
# Duração : 0.550304651260376 segundos
# Faltam 1805 itens na lista
# Inicio Item 2020
# Fim Item 2020
# Duração : 0.5467395782470703 segundos
# Faltam 1804 itens na lista
# Inicio Item 2021
# Fim Item 2021
# Duração : 0.5768337249755859 segundos
# Faltam 1803 itens na lista
# Inicio Item 2022
# Fim Item 2022
# Duração : 0.5657827854156494 segundos
# Faltam 1802 itens na lista
# Inicio Item 2023
# Fim Item 2023
# Duração : 0.6283211708068848 segundos
# Faltam 1801 itens na lista
# Inicio Item 2024
# Fim Item 2024
# Duração : 0.614595890045166 segundos
# Faltam 1800 itens na lista
# Inicio Item 2025
# Fim Item 2025
# Duração : 0.5991847515106201 segundos
# Faltam 1799 itens na lista
# Inicio Item 2026
# Fim Item 2026
# Duração : 0.6207315921783447 segundos
# Faltam 1798 itens na lista
# Inicio Item 2027
# Fim Item 2027
# Duração : 0.6882059574127197 segundos
# Faltam 1797 itens na lista
# Inicio Item 2028
# Fim Item 2028
# Duração : 0.6704180240631104 segundos
# Faltam 1796 itens na lista
# Inicio Item 2029
# Fim Item 2029
# Duração : 0.6802761554718018 segundos
# Faltam 1795 itens na lista
# Inicio Item 2030
# Fim Item 2030
# Duração : 0.7111036777496338 segundos
# Faltam 1794 itens na lista
# Inicio Item 2031
# Fim Item 2031
# Duração : 0.6617488861083984 segundos
# Faltam 1793 itens na lista
# Inicio Item 2032
# Fim Item 2032
# Duração : 0.7615668773651123 segundos
# Faltam 1792 itens na lista
# Inicio Item 2033
# Fim Item 2033
# Duração : 0.6378376483917236 segundos
# Faltam 1791 itens na lista
# Inicio Item 2034
# Fim Item 2034
# Duração : 0.673760175704956 segundos
# Faltam 1790 itens na lista
# Inicio Item 2035
# Fim Item 2035
# Duração : 0.7056968212127686 segundos
# Faltam 1789 itens na lista
# Inicio Item 2036
# Fim Item 2036
# Duração : 0.6800236701965332 segundos
# Faltam 1788 itens na lista
# Inicio Item 2037
# Fim Item 2037
# Duração : 0.6853811740875244 segundos
# Faltam 1787 itens na lista
# Inicio Item 2038
# Fim Item 2038
# Duração : 0.7267274856567383 segundos
# Faltam 1786 itens na lista
# Inicio Item 2039
# Fim Item 2039
# Duração : 0.8061275482177734 segundos
# Faltam 1785 itens na lista
# Inicio Item 2040
# Fim Item 2040
# Duração : 0.7528789043426514 segundos
# Faltam 1784 itens na lista
# Inicio Item 2041
# Fim Item 2041
# Duração : 0.7081801891326904 segundos
# Faltam 1783 itens na lista
# Inicio Item 2042
# Fim Item 2042
# Duração : 0.8455629348754883 segundos
# Faltam 1782 itens na lista
# Inicio Item 2043
# Fim Item 2043
# Duração : 1.3383653163909912 segundos
# Faltam 1781 itens na lista
# Inicio Item 2044
# Fim Item 2044
# Duração : 0.9041509628295898 segundos
# Faltam 1780 itens na lista
# Inicio Item 2045
# Fim Item 2045
# Duração : 0.8445897102355957 segundos
# Faltam 1779 itens na lista
# Inicio Item 2046
# Fim Item 2046
# Duração : 0.7623860836029053 segundos
# Faltam 1778 itens na lista
# Inicio Item 2047
# Fim Item 2047
# Duração : 0.906947135925293 segundos
# Faltam 1777 itens na lista
# Inicio Item 2048
# Fim Item 2048
# Duração : 0.9021706581115723 segundos
# Faltam 1776 itens na lista
# Inicio Item 2049
# Fim Item 2049
# Duração : 0.874434232711792 segundos
# Faltam 1775 itens na lista
# Inicio Item 2050
# Fim Item 2050
# Duração : 0.8120477199554443 segundos
# Faltam 1774 itens na lista
# Inicio Item 2051
# Fim Item 2051
# Duração : 0.8936159610748291 segundos
# Faltam 1773 itens na lista
# Inicio Item 2052
# Fim Item 2052
# Duração : 0.8759143352508545 segundos
# Faltam 1772 itens na lista
# Inicio Item 2053
# Fim Item 2053
# Duração : 0.9655616283416748 segundos
# Faltam 1771 itens na lista
# Inicio Item 2054
# Fim Item 2054
# Duração : 0.9010918140411377 segundos
# Faltam 1770 itens na lista
# Inicio Item 2055
# Fim Item 2055
# Duração : 0.9101223945617676 segundos
# Faltam 1769 itens na lista
# Inicio Item 2056
# Fim Item 2056
# Duração : 0.843925952911377 segundos
# Faltam 1768 itens na lista
# Inicio Item 2057
# Fim Item 2057
# Duração : 0.9921820163726807 segundos
# Faltam 1767 itens na lista
# Inicio Item 2058
# Fim Item 2058
# Duração : 1.053952932357788 segundos
# Faltam 1766 itens na lista
# Inicio Item 2059
# Fim Item 2059
# Duração : 1.0107567310333252 segundos
# Faltam 1765 itens na lista
# Inicio Item 2060
# Fim Item 2060
# Duração : 0.8378231525421143 segundos
# Faltam 1764 itens na lista
# Inicio Item 2061
# Fim Item 2061
# Duração : 0.9396438598632812 segundos
# Faltam 1763 itens na lista
# Inicio Item 2062
# Fim Item 2062
# Duração : 0.8456888198852539 segundos
# Faltam 1762 itens na lista
# Inicio Item 2063
# Fim Item 2063
# Duração : 0.9399411678314209 segundos
# Faltam 1761 itens na lista
# Inicio Item 2064
# Fim Item 2064
# Duração : 0.9531307220458984 segundos
# Faltam 1760 itens na lista
# Inicio Item 2065
# Fim Item 2065
# Duração : 0.9814999103546143 segundos
# Faltam 1759 itens na lista
# Inicio Item 2066
# Fim Item 2066
# Duração : 0.9428677558898926 segundos
# Faltam 1758 itens na lista
# Inicio Item 2067
# Fim Item 2067
# Duração : 0.9271833896636963 segundos
# Faltam 1757 itens na lista
# Inicio Item 2068
# Fim Item 2068
# Duração : 0.9426980018615723 segundos
# Faltam 1756 itens na lista
# Inicio Item 2069
# Fim Item 2069
# Duração : 0.9782135486602783 segundos
# Faltam 1755 itens na lista
# Inicio Item 2070
# Fim Item 2070
# Duração : 0.985975980758667 segundos
# Faltam 1754 itens na lista
# Inicio Item 2071
# Fim Item 2071
# Duração : 1.018836259841919 segundos
# Faltam 1753 itens na lista
# Inicio Item 2072
# Fim Item 2072
# Duração : 1.0501222610473633 segundos
# Faltam 1752 itens na lista
# Inicio Item 2073
# Fim Item 2073
# Duração : 1.0316121578216553 segundos
# Faltam 1751 itens na lista
# Inicio Item 2074
# Fim Item 2074
# Duração : 1.0234920978546143 segundos
# Faltam 1750 itens na lista
# Inicio Item 2075
# Fim Item 2075
# Duração : 1.077422857284546 segundos
# Faltam 1749 itens na lista
# Inicio Item 2076
# Fim Item 2076
# Duração : 1.0656208992004395 segundos
# Faltam 1748 itens na lista
# Inicio Item 2077
# Fim Item 2077
# Duração : 1.1412436962127686 segundos
# Faltam 1747 itens na lista
# Inicio Item 2078
# Fim Item 2078
# Duração : 1.0559430122375488 segundos
# Faltam 1746 itens na lista
# Inicio Item 2079
# Fim Item 2079
# Duração : 1.0455732345581055 segundos
# Faltam 1745 itens na lista
# Inicio Item 2080
# Fim Item 2080
# Duração : 1.0382006168365479 segundos
# Faltam 1744 itens na lista
# Inicio Item 2081
# Fim Item 2081
# Duração : 1.0440223217010498 segundos
# Faltam 1743 itens na lista
# Inicio Item 2082
# Fim Item 2082
# Duração : 1.0586879253387451 segundos
# Faltam 1742 itens na lista
# Inicio Item 2083
# Fim Item 2083
# Duração : 1.032829999923706 segundos
# Faltam 1741 itens na lista
# Inicio Item 2084
# Fim Item 2084
# Duração : 1.1005406379699707 segundos
# Faltam 1740 itens na lista
# Inicio Item 2085
# Fim Item 2085
# Duração : 1.2062790393829346 segundos
# Faltam 1739 itens na lista
# Inicio Item 2086
# Fim Item 2086
# Duração : 1.046236515045166 segundos
# Faltam 1738 itens na lista
# Inicio Item 2087
# Fim Item 2087
# Duração : 1.037426471710205 segundos
# Faltam 1737 itens na lista
# Inicio Item 2088
# Fim Item 2088
# Duração : 1.1468467712402344 segundos
# Faltam 1736 itens na lista
# Inicio Item 2089
# Fim Item 2089
# Duração : 1.163675308227539 segundos
# Faltam 1735 itens na lista
# Inicio Item 2090
# Fim Item 2090
# Duração : 1.0895187854766846 segundos
# Faltam 1734 itens na lista
# Inicio Item 2091
# Fim Item 2091
# Duração : 1.0685970783233643 segundos
# Faltam 1733 itens na lista
# Inicio Item 2092
# Fim Item 2092
# Duração : 1.1593761444091797 segundos
# Faltam 1732 itens na lista
# Inicio Item 2093
# Fim Item 2093
# Duração : 1.30216383934021 segundos
# Faltam 1731 itens na lista
# Inicio Item 2094
# Fim Item 2094
# Duração : 1.2620985507965088 segundos
# Faltam 1730 itens na lista
# Inicio Item 2095
# Fim Item 2095
# Duração : 1.2783832550048828 segundos
# Faltam 1729 itens na lista
# Inicio Item 2096
# Fim Item 2096
# Duração : 1.152432918548584 segundos
# Faltam 1728 itens na lista
# Inicio Item 2097
# Fim Item 2097
# Duração : 1.139054775238037 segundos
# Faltam 1727 itens na lista
# Inicio Item 2098
# Fim Item 2098
# Duração : 1.1612496376037598 segundos
# Faltam 1726 itens na lista
# Inicio Item 2099
# Fim Item 2099
# Duração : 1.1116981506347656 segundos
# Faltam 1725 itens na lista
# Inicio Item 2100
# Fim Item 2100
# Duração : 1.9169468879699707 segundos
# Faltam 1724 itens na lista
# Inicio Item 2101
# Fim Item 2101
# Duração : 1.2756218910217285 segundos
# Faltam 1723 itens na lista
# Inicio Item 2102
# Fim Item 2102
# Duração : 1.4203526973724365 segundos
# Faltam 1722 itens na lista
# Inicio Item 2103
# Fim Item 2103
# Duração : 1.1423017978668213 segundos
# Faltam 1721 itens na lista
# Inicio Item 2104
# Fim Item 2104
# Duração : 1.3707940578460693 segundos
# Faltam 1720 itens na lista
# Inicio Item 2105
# Fim Item 2105
# Duração : 1.3394215106964111 segundos
# Faltam 1719 itens na lista
# Inicio Item 2106
# Fim Item 2106
# Duração : 1.3475725650787354 segundos
# Faltam 1718 itens na lista
# Inicio Item 2107
# Fim Item 2107
# Duração : 1.3648383617401123 segundos
# Faltam 1717 itens na lista
# Inicio Item 2108
# Fim Item 2108
# Duração : 1.2826056480407715 segundos
# Faltam 1716 itens na lista
# Inicio Item 2109
# Fim Item 2109
# Duração : 1.4347221851348877 segundos
# Faltam 1715 itens na lista
# Inicio Item 2110
# Fim Item 2110
# Duração : 1.337693691253662 segundos
# Faltam 1714 itens na lista
# Inicio Item 2111
# Fim Item 2111
# Duração : 1.3000094890594482 segundos
# Faltam 1713 itens na lista
# Inicio Item 2112
# Fim Item 2112
# Duração : 1.3593804836273193 segundos
# Faltam 1712 itens na lista
# Inicio Item 2113
# Fim Item 2113
# Duração : 1.2695045471191406 segundos
# Faltam 1711 itens na lista
# Inicio Item 2114
# Fim Item 2114
# Duração : 1.3105943202972412 segundos
# Faltam 1710 itens na lista
# Inicio Item 2115
# Fim Item 2115
# Duração : 1.3888390064239502 segundos
# Faltam 1709 itens na lista
# Inicio Item 2116
# Fim Item 2116
# Duração : 1.3999357223510742 segundos
# Faltam 1708 itens na lista
# Inicio Item 2117
# Fim Item 2117
# Duração : 1.3750174045562744 segundos
# Faltam 1707 itens na lista
# Inicio Item 2118
# Fim Item 2118
# Duração : 1.3993184566497803 segundos
# Faltam 1706 itens na lista
# Inicio Item 2119
# Fim Item 2119
# Duração : 1.2334213256835938 segundos
# Faltam 1705 itens na lista
# Inicio Item 2120
# Fim Item 2120
# Duração : 1.4655416011810303 segundos
# Faltam 1704 itens na lista
# Inicio Item 2121
# Fim Item 2121
# Duração : 1.3959543704986572 segundos
# Faltam 1703 itens na lista
# Inicio Item 2122
# Fim Item 2122
# Duração : 1.3708138465881348 segundos
# Faltam 1702 itens na lista
# Inicio Item 2123
# Fim Item 2123
# Duração : 1.4663481712341309 segundos
# Faltam 1701 itens na lista
# Inicio Item 2124
# Fim Item 2124
# Duração : 1.7076997756958008 segundos
# Faltam 1700 itens na lista
# Inicio Item 2125
# Fim Item 2125
# Duração : 1.3216147422790527 segundos
# Faltam 1699 itens na lista
# Inicio Item 2126
# Fim Item 2126
# Duração : 1.4111871719360352 segundos
# Faltam 1698 itens na lista
# Inicio Item 2127
# Fim Item 2127
# Duração : 1.4643669128417969 segundos
# Faltam 1697 itens na lista
# Inicio Item 2128
# Fim Item 2128
# Duração : 1.5573163032531738 segundos
# Faltam 1696 itens na lista
# Inicio Item 2129
# Fim Item 2129
# Duração : 1.4350261688232422 segundos
# Faltam 1695 itens na lista
# Inicio Item 2130
# Fim Item 2130
# Duração : 1.4400720596313477 segundos
# Faltam 1694 itens na lista
# Inicio Item 2131
# Fim Item 2131
# Duração : 1.3393487930297852 segundos
# Faltam 1693 itens na lista
# Inicio Item 2132
# Fim Item 2132
# Duração : 1.4297661781311035 segundos
# Faltam 1692 itens na lista
# Inicio Item 2133
# Fim Item 2133
# Duração : 1.5757014751434326 segundos
# Faltam 1691 itens na lista
# Inicio Item 2134
# Fim Item 2134
# Duração : 1.4663946628570557 segundos
# Faltam 1690 itens na lista
# Inicio Item 2135
# Fim Item 2135
# Duração : 1.4496257305145264 segundos
# Faltam 1689 itens na lista
# Inicio Item 2136
# Fim Item 2136
# Duração : 1.3757638931274414 segundos
# Faltam 1688 itens na lista
# Inicio Item 2137
# Fim Item 2137
# Duração : 1.699887752532959 segundos
# Faltam 1687 itens na lista
# Inicio Item 2138
# Fim Item 2138
# Duração : 1.601783037185669 segundos
# Faltam 1686 itens na lista
# Inicio Item 2139
# Fim Item 2139
# Duração : 1.605586051940918 segundos
# Faltam 1685 itens na lista
# Inicio Item 2140
# Fim Item 2140
# Duração : 1.4179234504699707 segundos
# Faltam 1684 itens na lista
# Inicio Item 2141
# Fim Item 2141
# Duração : 1.530076503753662 segundos
# Faltam 1683 itens na lista
# Inicio Item 2142
# Fim Item 2142
# Duração : 1.5346457958221436 segundos
# Faltam 1682 itens na lista
# Inicio Item 2143
# Fim Item 2143
# Duração : 1.6573317050933838 segundos
# Faltam 1681 itens na lista
# Inicio Item 2144
# Fim Item 2144
# Duração : 1.5679492950439453 segundos
# Faltam 1680 itens na lista
# Inicio Item 2145
# Fim Item 2145
# Duração : 1.5505919456481934 segundos
# Faltam 1679 itens na lista
# Inicio Item 2146
# Fim Item 2146
# Duração : 1.4865107536315918 segundos
# Faltam 1678 itens na lista
# Inicio Item 2147
# Fim Item 2147
# Duração : 1.5636317729949951 segundos
# Faltam 1677 itens na lista
# Inicio Item 2148
# Fim Item 2148
# Duração : 1.5278348922729492 segundos
# Faltam 1676 itens na lista
# Inicio Item 2149
# Fim Item 2149
# Duração : 1.511653184890747 segundos
# Faltam 1675 itens na lista
# Inicio Item 2150
# Fim Item 2150
# Duração : 1.6108977794647217 segundos
# Faltam 1674 itens na lista
# Inicio Item 2151
# Fim Item 2151
# Duração : 1.5961432456970215 segundos
# Faltam 1673 itens na lista
# Inicio Item 2152
# Fim Item 2152
# Duração : 1.5382280349731445 segundos
# Faltam 1672 itens na lista
# Inicio Item 2153
# Fim Item 2153
# Duração : 1.698706865310669 segundos
# Faltam 1671 itens na lista
# Inicio Item 2154
# Fim Item 2154
# Duração : 1.6608662605285645 segundos
# Faltam 1670 itens na lista
# Inicio Item 2155
# Fim Item 2155
# Duração : 1.701068639755249 segundos
# Faltam 1669 itens na lista
# Inicio Item 2156
# Fim Item 2156
# Duração : 1.6753087043762207 segundos
# Faltam 1668 itens na lista
# Inicio Item 2157
# Fim Item 2157
# Duração : 1.643387794494629 segundos
# Faltam 1667 itens na lista
# Inicio Item 2158
# Fim Item 2158
# Duração : 1.6651463508605957 segundos
# Faltam 1666 itens na lista
# Inicio Item 2159
# Fim Item 2159
# Duração : 1.6500072479248047 segundos
# Faltam 1665 itens na lista
# Inicio Item 2160
# Fim Item 2160
# Duração : 1.5518417358398438 segundos
# Faltam 1664 itens na lista
# Inicio Item 2161
# Fim Item 2161
# Duração : 1.5920135974884033 segundos
# Faltam 1663 itens na lista
# Inicio Item 2162
# Fim Item 2162
# Duração : 1.8238248825073242 segundos
# Faltam 1662 itens na lista
# Inicio Item 2163
# Fim Item 2163
# Duração : 1.8932201862335205 segundos
# Faltam 1661 itens na lista
# Inicio Item 2164
# Fim Item 2164
# Duração : 1.7122044563293457 segundos
# Faltam 1660 itens na lista
# Inicio Item 2165
# Fim Item 2165
# Duração : 1.841684103012085 segundos
# Faltam 1659 itens na lista
# Inicio Item 2166
# Fim Item 2166
# Duração : 1.7112414836883545 segundos
# Faltam 1658 itens na lista
# Inicio Item 2167
# Fim Item 2167
# Duração : 1.7454907894134521 segundos
# Faltam 1657 itens na lista
# Inicio Item 2168
# Fim Item 2168
# Duração : 1.7688500881195068 segundos
# Faltam 1656 itens na lista
# Inicio Item 2169
# Fim Item 2169
# Duração : 1.7410657405853271 segundos
# Faltam 1655 itens na lista
# Inicio Item 2170
# Fim Item 2170
# Duração : 1.9411406517028809 segundos
# Faltam 1654 itens na lista
# Inicio Item 2171
# Fim Item 2171
# Duração : 1.7651443481445312 segundos
# Faltam 1653 itens na lista
# Inicio Item 2172
# Fim Item 2172
# Duração : 1.907867670059204 segundos
# Faltam 1652 itens na lista
# Inicio Item 2173
# Fim Item 2173
# Duração : 2.0282483100891113 segundos
# Faltam 1651 itens na lista
# Inicio Item 2174
# Fim Item 2174
# Duração : 1.8985252380371094 segundos
# Faltam 1650 itens na lista
# Inicio Item 2175
# Fim Item 2175
# Duração : 1.7371292114257812 segundos
# Faltam 1649 itens na lista
# Inicio Item 2176
# Fim Item 2176
# Duração : 2.1761679649353027 segundos
# Faltam 1648 itens na lista
# Inicio Item 2177
# Fim Item 2177
# Duração : 1.8041167259216309 segundos
# Faltam 1647 itens na lista
# Inicio Item 2178
# Fim Item 2178
# Duração : 1.7629766464233398 segundos
# Faltam 1646 itens na lista
# Inicio Item 2179
# Fim Item 2179
# Duração : 1.854745626449585 segundos
# Faltam 1645 itens na lista
# Inicio Item 2180
# Fim Item 2180
# Duração : 1.7420079708099365 segundos
# Faltam 1644 itens na lista
# Inicio Item 2181
# Fim Item 2181
# Duração : 1.8130271434783936 segundos
# Faltam 1643 itens na lista
# Inicio Item 2182
# Fim Item 2182
# Duração : 1.8961288928985596 segundos
# Faltam 1642 itens na lista
# Inicio Item 2183
# Fim Item 2183
# Duração : 2.307584524154663 segundos
# Faltam 1641 itens na lista
# Inicio Item 2184
# Fim Item 2184
# Duração : 1.8433146476745605 segundos
# Faltam 1640 itens na lista
# Inicio Item 2185
# Fim Item 2185
# Duração : 1.887646198272705 segundos
# Faltam 1639 itens na lista
# Inicio Item 2186
# Fim Item 2186
# Duração : 1.816767930984497 segundos
# Faltam 1638 itens na lista
# Inicio Item 2187
# Fim Item 2187
# Duração : 1.822995662689209 segundos
# Faltam 1637 itens na lista
# Inicio Item 2188
# Fim Item 2188
# Duração : 1.8874106407165527 segundos
# Faltam 1636 itens na lista
# Inicio Item 2189
# Fim Item 2189
# Duração : 1.9204702377319336 segundos
# Faltam 1635 itens na lista
# Inicio Item 2190
# Fim Item 2190
# Duração : 1.7678954601287842 segundos
# Faltam 1634 itens na lista
# Inicio Item 2191
# Fim Item 2191
# Duração : 1.9131226539611816 segundos
# Faltam 1633 itens na lista
# Inicio Item 2192
# Fim Item 2192
# Duração : 1.8961846828460693 segundos
# Faltam 1632 itens na lista
# Inicio Item 2193
# Fim Item 2193
# Duração : 1.9616296291351318 segundos
# Faltam 1631 itens na lista
# Inicio Item 2194
# Fim Item 2194
# Duração : 1.8781108856201172 segundos
# Faltam 1630 itens na lista
# Inicio Item 2195
# Fim Item 2195
# Duração : 1.993051290512085 segundos
# Faltam 1629 itens na lista
# Inicio Item 2196
# Fim Item 2196
# Duração : 1.9196040630340576 segundos
# Faltam 1628 itens na lista
# Inicio Item 2197
# Fim Item 2197
# Duração : 1.905256748199463 segundos
# Faltam 1627 itens na lista
# Inicio Item 2198
# Fim Item 2198
# Duração : 1.9192688465118408 segundos
# Faltam 1626 itens na lista
# Inicio Item 2199
# Fim Item 2199
# Duração : 1.9284021854400635 segundos
# Faltam 1625 itens na lista
# Inicio Item 2200
# Fim Item 2200
# Duração : 3.2393972873687744 segundos
# Faltam 1624 itens na lista
# Inicio Item 2201
# Fim Item 2201
# Duração : 1.8493809700012207 segundos
# Faltam 1623 itens na lista
# Inicio Item 2202
# Fim Item 2202
# Duração : 1.9936764240264893 segundos
# Faltam 1622 itens na lista
# Inicio Item 2203
# Fim Item 2203
# Duração : 2.0157601833343506 segundos
# Faltam 1621 itens na lista
# Inicio Item 2204
# Fim Item 2204
# Duração : 2.297431707382202 segundos
# Faltam 1620 itens na lista
# Inicio Item 2205
# Fim Item 2205
# Duração : 1.9761736392974854 segundos
# Faltam 1619 itens na lista
# Inicio Item 2206
# Fim Item 2206
# Duração : 1.994337797164917 segundos
# Faltam 1618 itens na lista
# Inicio Item 2207
# Fim Item 2207
# Duração : 2.016461133956909 segundos
# Faltam 1617 itens na lista
# Inicio Item 2208
# Fim Item 2208
# Duração : 2.456681489944458 segundos
# Faltam 1616 itens na lista
# Inicio Item 2209
# Fim Item 2209
# Duração : 2.092559337615967 segundos
# Faltam 1615 itens na lista
# Inicio Item 2210
# Fim Item 2210
# Duração : 2.0663092136383057 segundos
# Faltam 1614 itens na lista
# Inicio Item 2211
# Fim Item 2211
# Duração : 1.9609630107879639 segundos
# Faltam 1613 itens na lista
# Inicio Item 2212
# Fim Item 2212
# Duração : 2.0710060596466064 segundos
# Faltam 1612 itens na lista
# Inicio Item 2213
# Fim Item 2213
# Duração : 2.061875343322754 segundos
# Faltam 1611 itens na lista
# Inicio Item 2214
# Fim Item 2214
# Duração : 1.9522664546966553 segundos
# Faltam 1610 itens na lista
# Inicio Item 2215
# Fim Item 2215
# Duração : 2.0588808059692383 segundos
# Faltam 1609 itens na lista
# Inicio Item 2216
# Fim Item 2216
# Duração : 2.0641372203826904 segundos
# Faltam 1608 itens na lista
# Inicio Item 2217
# Fim Item 2217
# Duração : 1.9771716594696045 segundos
# Faltam 1607 itens na lista
# Inicio Item 2218
# Fim Item 2218
# Duração : 2.083592414855957 segundos
# Faltam 1606 itens na lista
# Inicio Item 2219
# Fim Item 2219
# Duração : 2.0820164680480957 segundos
# Faltam 1605 itens na lista
# Inicio Item 2220
# Fim Item 2220
# Duração : 2.122365713119507 segundos
# Faltam 1604 itens na lista
# Inicio Item 2221
# Fim Item 2221
# Duração : 2.065371036529541 segundos
# Faltam 1603 itens na lista
# Inicio Item 2222
# Fim Item 2222
# Duração : 1.9871318340301514 segundos
# Faltam 1602 itens na lista
# Inicio Item 2223
# Fim Item 2223
# Duração : 2.2038185596466064 segundos
# Faltam 1601 itens na lista
# Inicio Item 2224
# Fim Item 2224
# Duração : 2.2454938888549805 segundos
# Faltam 1600 itens na lista
# Inicio Item 2225
# Fim Item 2225
# Duração : 2.083632707595825 segundos
# Faltam 1599 itens na lista
# Inicio Item 2226
# Fim Item 2226
# Duração : 2.0184273719787598 segundos
# Faltam 1598 itens na lista
# Inicio Item 2227
# Fim Item 2227
# Duração : 2.1609292030334473 segundos
# Faltam 1597 itens na lista
# Inicio Item 2228
# Fim Item 2228
# Duração : 2.083862543106079 segundos
# Faltam 1596 itens na lista
# Inicio Item 2229
# Fim Item 2229
# Duração : 2.203456401824951 segundos
# Faltam 1595 itens na lista
# Inicio Item 2230
# Fim Item 2230
# Duração : 2.0678749084472656 segundos
# Faltam 1594 itens na lista
# Inicio Item 2231
# Fim Item 2231
# Duração : 2.1859002113342285 segundos
# Faltam 1593 itens na lista
# Inicio Item 2232
# Fim Item 2232
# Duração : 2.3156087398529053 segundos
# Faltam 1592 itens na lista
# Inicio Item 2233
# Fim Item 2233
# Duração : 2.286139965057373 segundos
# Faltam 1591 itens na lista
# Inicio Item 2234
# Fim Item 2234
# Duração : 2.217315435409546 segundos
# Faltam 1590 itens na lista
# Inicio Item 2235
# Fim Item 2235
# Duração : 2.1594576835632324 segundos
# Faltam 1589 itens na lista
# Inicio Item 2236
# Fim Item 2236
# Duração : 2.3275821208953857 segundos
# Faltam 1588 itens na lista
# Inicio Item 2237
# Fim Item 2237
# Duração : 2.573115587234497 segundos
# Faltam 1587 itens na lista
# Inicio Item 2238
# Fim Item 2238
# Duração : 2.3448703289031982 segundos
# Faltam 1586 itens na lista
# Inicio Item 2239
# Fim Item 2239
# Duração : 2.162743091583252 segundos
# Faltam 1585 itens na lista
# Inicio Item 2240
# Fim Item 2240
# Duração : 2.3982927799224854 segundos
# Faltam 1584 itens na lista
# Inicio Item 2241
# Fim Item 2241
# Duração : 2.3286736011505127 segundos
# Faltam 1583 itens na lista
# Inicio Item 2242
# Fim Item 2242
# Duração : 2.3634936809539795 segundos
# Faltam 1582 itens na lista
# Inicio Item 2243
# Fim Item 2243
# Duração : 2.5634026527404785 segundos
# Faltam 1581 itens na lista
# Inicio Item 2244
# Fim Item 2244
# Duração : 2.4055895805358887 segundos
# Faltam 1580 itens na lista
# Inicio Item 2245
# Fim Item 2245
# Duração : 2.3638370037078857 segundos
# Faltam 1579 itens na lista
# Inicio Item 2246
# Fim Item 2246
# Duração : 2.359171152114868 segundos
# Faltam 1578 itens na lista
# Inicio Item 2247
# Fim Item 2247
# Duração : 2.418351173400879 segundos
# Faltam 1577 itens na lista
# Inicio Item 2248
# Fim Item 2248
# Duração : 2.3540613651275635 segundos
# Faltam 1576 itens na lista
# Inicio Item 2249
# Fim Item 2249
# Duração : 2.386918544769287 segundos
# Faltam 1575 itens na lista
# Inicio Item 2250
# Fim Item 2250
# Duração : 4.177802324295044 segundos
# Faltam 1574 itens na lista
# Inicio Item 2251
# Fim Item 2251
# Duração : 2.523883819580078 segundos
# Faltam 1573 itens na lista
# Inicio Item 2252
# Fim Item 2252
# Duração : 2.3847098350524902 segundos
# Faltam 1572 itens na lista
# Inicio Item 2253
# Fim Item 2253
# Duração : 2.506056308746338 segundos
# Faltam 1571 itens na lista
# Inicio Item 2254
# Fim Item 2254
# Duração : 2.408982753753662 segundos
# Faltam 1570 itens na lista
# Inicio Item 2255
# Fim Item 2255
# Duração : 2.4833524227142334 segundos
# Faltam 1569 itens na lista
# Inicio Item 2256
# Fim Item 2256
# Duração : 2.3870151042938232 segundos
# Faltam 1568 itens na lista
# Inicio Item 2257
# Fim Item 2257
# Duração : 2.71734619140625 segundos
# Faltam 1567 itens na lista
# Inicio Item 2258
# Fim Item 2258
# Duração : 2.3701679706573486 segundos
# Faltam 1566 itens na lista
# Inicio Item 2259
# Fim Item 2259
# Duração : 2.447605609893799 segundos
# Faltam 1565 itens na lista
# Inicio Item 2260
# Fim Item 2260
# Duração : 2.4284658432006836 segundos
# Faltam 1564 itens na lista
# Inicio Item 2261
# Fim Item 2261
# Duração : 2.589937210083008 segundos
# Faltam 1563 itens na lista
# Inicio Item 2262
# Fim Item 2262
# Duração : 2.396094560623169 segundos
# Faltam 1562 itens na lista
# Inicio Item 2263
# Fim Item 2263
# Duração : 2.3318636417388916 segundos
# Faltam 1561 itens na lista
# Inicio Item 2264
# Fim Item 2264
# Duração : 2.4267570972442627 segundos
# Faltam 1560 itens na lista
# Inicio Item 2265
# Fim Item 2265
# Duração : 2.4401071071624756 segundos
# Faltam 1559 itens na lista
# Inicio Item 2266
# Fim Item 2266
# Duração : 2.446045160293579 segundos
# Faltam 1558 itens na lista
# Inicio Item 2267
# Fim Item 2267
# Duração : 2.3350229263305664 segundos
# Faltam 1557 itens na lista
# Inicio Item 2268
# Fim Item 2268
# Duração : 2.5090408325195312 segundos
# Faltam 1556 itens na lista
# Inicio Item 2269
# Fim Item 2269
# Duração : 2.467496395111084 segundos
# Faltam 1555 itens na lista
# Inicio Item 2270
# Fim Item 2270
# Duração : 2.377152442932129 segundos
# Faltam 1554 itens na lista
# Inicio Item 2271
# Fim Item 2271
# Duração : 2.471388816833496 segundos
# Faltam 1553 itens na lista
# Inicio Item 2272
# Fim Item 2272
# Duração : 2.570474147796631 segundos
# Faltam 1552 itens na lista
# Inicio Item 2273
# Fim Item 2273
# Duração : 2.6177589893341064 segundos
# Faltam 1551 itens na lista
# Inicio Item 2274
# Fim Item 2274
# Duração : 2.552278518676758 segundos
# Faltam 1550 itens na lista
# Inicio Item 2275
# Fim Item 2275
# Duração : 2.511925220489502 segundos
# Faltam 1549 itens na lista
# Inicio Item 2276
# Fim Item 2276
# Duração : 2.4267799854278564 segundos
# Faltam 1548 itens na lista
# Inicio Item 2277
# Fim Item 2277
# Duração : 2.528864860534668 segundos
# Faltam 1547 itens na lista
# Inicio Item 2278
# Fim Item 2278
# Duração : 2.5097830295562744 segundos
# Faltam 1546 itens na lista
# Inicio Item 2279
# Fim Item 2279
# Duração : 2.412346363067627 segundos
# Faltam 1545 itens na lista
# Inicio Item 2280
# Fim Item 2280
# Duração : 2.5464866161346436 segundos
# Faltam 1544 itens na lista
# Inicio Item 2281
# Fim Item 2281
# Duração : 2.7934186458587646 segundos
# Faltam 1543 itens na lista
# Inicio Item 2282
# Fim Item 2282
# Duração : 2.639292001724243 segundos
# Faltam 1542 itens na lista
# Inicio Item 2283
# Fim Item 2283
# Duração : 2.6536781787872314 segundos
# Faltam 1541 itens na lista
# Inicio Item 2284
# Fim Item 2284
# Duração : 2.492966413497925 segundos
# Faltam 1540 itens na lista
# Inicio Item 2285
# Fim Item 2285
# Duração : 2.7596120834350586 segundos
# Faltam 1539 itens na lista
# Inicio Item 2286
# Fim Item 2286
# Duração : 2.579616069793701 segundos
# Faltam 1538 itens na lista
# Inicio Item 2287
# Fim Item 2287
# Duração : 2.5987932682037354 segundos
# Faltam 1537 itens na lista
# Inicio Item 2288
# Fim Item 2288
# Duração : 2.5395004749298096 segundos
# Faltam 1536 itens na lista
# Inicio Item 2289
# Fim Item 2289
# Duração : 2.7539732456207275 segundos
# Faltam 1535 itens na lista
# Inicio Item 2290
# Fim Item 2290
# Duração : 2.6535189151763916 segundos
# Faltam 1534 itens na lista
# Inicio Item 2291
# Fim Item 2291
# Duração : 2.6086905002593994 segundos
# Faltam 1533 itens na lista
# Inicio Item 2292
# Fim Item 2292
# Duração : 2.6639297008514404 segundos
# Faltam 1532 itens na lista
# Inicio Item 2293
# Fim Item 2293
# Duração : 2.5356552600860596 segundos
# Faltam 1531 itens na lista
# Inicio Item 2294
# Fim Item 2294
# Duração : 2.6945667266845703 segundos
# Faltam 1530 itens na lista
# Inicio Item 2295
# Fim Item 2295
# Duração : 2.6225287914276123 segundos
# Faltam 1529 itens na lista
# Inicio Item 2296
# Fim Item 2296
# Duração : 2.6535942554473877 segundos
# Faltam 1528 itens na lista
# Inicio Item 2297
# Fim Item 2297
# Duração : 2.8180925846099854 segundos
# Faltam 1527 itens na lista
# Inicio Item 2298
# Fim Item 2298
# Duração : 2.6466877460479736 segundos
# Faltam 1526 itens na lista
# Inicio Item 2299
# Fim Item 2299
# Duração : 2.658144950866699 segundos
# Faltam 1525 itens na lista
# Inicio Item 2300
# Fim Item 2300
# Duração : 2.761563301086426 segundos
# Faltam 1524 itens na lista
# Inicio Item 2301
# Fim Item 2301
# Duração : 2.5794758796691895 segundos
# Faltam 1523 itens na lista
# Inicio Item 2302
# Fim Item 2302
# Duração : 2.692028045654297 segundos
# Faltam 1522 itens na lista
# Inicio Item 2303
# Fim Item 2303
# Duração : 2.808809518814087 segundos
# Faltam 1521 itens na lista
# Inicio Item 2304
# Fim Item 2304
# Duração : 3.308068037033081 segundos
# Faltam 1520 itens na lista
# Inicio Item 2305
# Fim Item 2305
# Duração : 2.7186033725738525 segundos
# Faltam 1519 itens na lista
# Inicio Item 2306
# Fim Item 2306
# Duração : 2.7888224124908447 segundos
# Faltam 1518 itens na lista
# Inicio Item 2307
# Fim Item 2307
# Duração : 2.9510037899017334 segundos
# Faltam 1517 itens na lista
# Inicio Item 2308
# Fim Item 2308
# Duração : 2.7535860538482666 segundos
# Faltam 1516 itens na lista
# Inicio Item 2309
# Fim Item 2309
# Duração : 2.739736557006836 segundos
# Faltam 1515 itens na lista
# Inicio Item 2310
# Fim Item 2310
# Duração : 2.8766825199127197 segundos
# Faltam 1514 itens na lista
# Inicio Item 2311
# Fim Item 2311
# Duração : 2.694777488708496 segundos
# Faltam 1513 itens na lista
# Inicio Item 2312
# Fim Item 2312
# Duração : 2.767167091369629 segundos
# Faltam 1512 itens na lista
# Inicio Item 2313
# Fim Item 2313
# Duração : 2.845977306365967 segundos
# Faltam 1511 itens na lista
# Inicio Item 2314
# Fim Item 2314
# Duração : 2.808680295944214 segundos
# Faltam 1510 itens na lista
# Inicio Item 2315
# Fim Item 2315
# Duração : 2.6902546882629395 segundos
# Faltam 1509 itens na lista
# Inicio Item 2316
# Fim Item 2316
# Duração : 2.7909300327301025 segundos
# Faltam 1508 itens na lista
# Inicio Item 2317
# Fim Item 2317
# Duração : 2.8171141147613525 segundos
# Faltam 1507 itens na lista
# Inicio Item 2318
# Fim Item 2318
# Duração : 3.0340640544891357 segundos
# Faltam 1506 itens na lista
# Inicio Item 2319
# Fim Item 2319
# Duração : 2.812166452407837 segundos
# Faltam 1505 itens na lista
# Inicio Item 2320
# Fim Item 2320
# Duração : 2.7294692993164062 segundos
# Faltam 1504 itens na lista
# Inicio Item 2321
# Fim Item 2321
# Duração : 2.858949899673462 segundos
# Faltam 1503 itens na lista
# Inicio Item 2322
# Fim Item 2322
# Duração : 2.7115395069122314 segundos
# Faltam 1502 itens na lista
# Inicio Item 2323
# Fim Item 2323
# Duração : 2.83882474899292 segundos
# Faltam 1501 itens na lista
# Inicio Item 2324
# Fim Item 2324
# Duração : 2.7294723987579346 segundos
# Faltam 1500 itens na lista
# Inicio Item 2325
# Fim Item 2325
# Duração : 3.333042860031128 segundos
# Faltam 1499 itens na lista
# Inicio Item 2326
# Fim Item 2326
# Duração : 2.842501640319824 segundos
# Faltam 1498 itens na lista
# Inicio Item 2327
# Fim Item 2327
# Duração : 2.878183364868164 segundos
# Faltam 1497 itens na lista
# Inicio Item 2328
# Fim Item 2328
# Duração : 3.135064125061035 segundos
# Faltam 1496 itens na lista
# Inicio Item 2329
# Fim Item 2329
# Duração : 2.8245372772216797 segundos
# Faltam 1495 itens na lista
# Inicio Item 2330
# Fim Item 2330
# Duração : 2.9216020107269287 segundos
# Faltam 1494 itens na lista
# Inicio Item 2331
# Fim Item 2331
# Duração : 2.894202709197998 segundos
# Faltam 1493 itens na lista
# Inicio Item 2332
# Fim Item 2332
# Duração : 2.9961578845977783 segundos
# Faltam 1492 itens na lista
# Inicio Item 2333
# Fim Item 2333
# Duração : 2.9535460472106934 segundos
# Faltam 1491 itens na lista
# Inicio Item 2334
# Fim Item 2334
# Duração : 2.8036558628082275 segundos
# Faltam 1490 itens na lista
# Inicio Item 2335
# Fim Item 2335
# Duração : 3.143585205078125 segundos
# Faltam 1489 itens na lista
# Inicio Item 2336
# Fim Item 2336
# Duração : 3.208585739135742 segundos
# Faltam 1488 itens na lista
# Inicio Item 2337
# Fim Item 2337
# Duração : 3.062328338623047 segundos
# Faltam 1487 itens na lista
# Inicio Item 2338
# Fim Item 2338
# Duração : 3.6221871376037598 segundos
# Faltam 1486 itens na lista
# Inicio Item 2339
# Fim Item 2339
# Duração : 3.1478936672210693 segundos
# Faltam 1485 itens na lista
# Inicio Item 2340
# Fim Item 2340
# Duração : 3.2915918827056885 segundos
# Faltam 1484 itens na lista
# Inicio Item 2341
# Fim Item 2341
# Duração : 3.161217451095581 segundos
# Faltam 1483 itens na lista
# Inicio Item 2342
# Fim Item 2342
# Duração : 2.9523508548736572 segundos
# Faltam 1482 itens na lista
# Inicio Item 2343
# Fim Item 2343
# Duração : 2.976597309112549 segundos
# Faltam 1481 itens na lista
# Inicio Item 2344
# Fim Item 2344
# Duração : 3.2680819034576416 segundos
# Faltam 1480 itens na lista
# Inicio Item 2345
# Fim Item 2345
# Duração : 3.250174045562744 segundos
# Faltam 1479 itens na lista
# Inicio Item 2346
# Fim Item 2346
# Duração : 3.0623703002929688 segundos
# Faltam 1478 itens na lista
# Inicio Item 2347
# Fim Item 2347
# Duração : 3.223414182662964 segundos
# Faltam 1477 itens na lista
# Inicio Item 2348
# Fim Item 2348
# Duração : 3.4560301303863525 segundos
# Faltam 1476 itens na lista
# Inicio Item 2349
# Fim Item 2349
# Duração : 2.9244585037231445 segundos
# Faltam 1475 itens na lista
# Inicio Item 2350
# Fim Item 2350
# Duração : 3.8838136196136475 segundos
# Faltam 1474 itens na lista
# Inicio Item 2351
# Fim Item 2351
# Duração : 3.1244473457336426 segundos
# Faltam 1473 itens na lista
# Inicio Item 2352
# Fim Item 2352
# Duração : 3.0591917037963867 segundos
# Faltam 1472 itens na lista
# Inicio Item 2353
# Fim Item 2353
# Duração : 3.065715789794922 segundos
# Faltam 1471 itens na lista
# Inicio Item 2354
# Fim Item 2354
# Duração : 3.085744857788086 segundos
# Faltam 1470 itens na lista
# Inicio Item 2355
# Fim Item 2355
# Duração : 3.1161317825317383 segundos
# Faltam 1469 itens na lista
# Inicio Item 2356
# Fim Item 2356
# Duração : 2.9633171558380127 segundos
# Faltam 1468 itens na lista
# Inicio Item 2357
# Fim Item 2357
# Duração : 3.3474831581115723 segundos
# Faltam 1467 itens na lista
# Inicio Item 2358
# Fim Item 2358
# Duração : 3.1223721504211426 segundos
# Faltam 1466 itens na lista
# Inicio Item 2359
# Fim Item 2359
# Duração : 3.1338911056518555 segundos
# Faltam 1465 itens na lista
# Inicio Item 2360
# Fim Item 2360
# Duração : 3.6857070922851562 segundos
# Faltam 1464 itens na lista
# Inicio Item 2361
# Fim Item 2361
# Duração : 3.259653091430664 segundos
# Faltam 1463 itens na lista
# Inicio Item 2362
# Fim Item 2362
# Duração : 3.3284430503845215 segundos
# Faltam 1462 itens na lista
# Inicio Item 2363
# Fim Item 2363
# Duração : 3.6930296421051025 segundos
# Faltam 1461 itens na lista
# Inicio Item 2364
# Fim Item 2364
# Duração : 3.1103293895721436 segundos
# Faltam 1460 itens na lista
# Inicio Item 2365
# Fim Item 2365
# Duração : 3.3192715644836426 segundos
# Faltam 1459 itens na lista
# Inicio Item 2366
# Fim Item 2366
# Duração : 3.4598872661590576 segundos
# Faltam 1458 itens na lista
# Inicio Item 2367
# Fim Item 2367
# Duração : 3.246663808822632 segundos
# Faltam 1457 itens na lista
# Inicio Item 2368
# Fim Item 2368
# Duração : 3.1798787117004395 segundos
# Faltam 1456 itens na lista
# Inicio Item 2369
# Fim Item 2369
# Duração : 3.216845750808716 segundos
# Faltam 1455 itens na lista
# Inicio Item 2370
# Fim Item 2370
# Duração : 3.2174277305603027 segundos
# Faltam 1454 itens na lista
# Inicio Item 2371
# Fim Item 2371
# Duração : 3.2208361625671387 segundos
# Faltam 1453 itens na lista
# Inicio Item 2372
# Fim Item 2372
# Duração : 3.295933485031128 segundos
# Faltam 1452 itens na lista
# Inicio Item 2373
# Fim Item 2373
# Duração : 3.2617390155792236 segundos
# Faltam 1451 itens na lista
# Inicio Item 2374
# Fim Item 2374
# Duração : 3.1730453968048096 segundos
# Faltam 1450 itens na lista
# Inicio Item 2375
# Fim Item 2375
# Duração : 3.728053331375122 segundos
# Faltam 1449 itens na lista
# Inicio Item 2376
# Fim Item 2376
# Duração : 3.3862786293029785 segundos
# Faltam 1448 itens na lista
# Inicio Item 2377
# Fim Item 2377
# Duração : 3.601768732070923 segundos
# Faltam 1447 itens na lista
# Inicio Item 2378
# Fim Item 2378
# Duração : 3.203540802001953 segundos
# Faltam 1446 itens na lista
# Inicio Item 2379
# Fim Item 2379
# Duração : 3.2555906772613525 segundos
# Faltam 1445 itens na lista
# Inicio Item 2380
# Fim Item 2380
# Duração : 3.3308913707733154 segundos
# Faltam 1444 itens na lista
# Inicio Item 2381
# Fim Item 2381
# Duração : 3.5932226181030273 segundos
# Faltam 1443 itens na lista
# Inicio Item 2382
# Fim Item 2382
# Duração : 3.5954418182373047 segundos
# Faltam 1442 itens na lista
# Inicio Item 2383
# Fim Item 2383
# Duração : 3.574483633041382 segundos
# Faltam 1441 itens na lista
# Inicio Item 2384
# Fim Item 2384
# Duração : 3.8776373863220215 segundos
# Faltam 1440 itens na lista
# Inicio Item 2385
# Fim Item 2385
# Duração : 3.4413506984710693 segundos
# Faltam 1439 itens na lista
# Inicio Item 2386
# Fim Item 2386
# Duração : 3.6556670665740967 segundos
# Faltam 1438 itens na lista
# Inicio Item 2387
# Fim Item 2387
# Duração : 3.6667702198028564 segundos
# Faltam 1437 itens na lista
# Inicio Item 2388
# Fim Item 2388
# Duração : 3.377926826477051 segundos
# Faltam 1436 itens na lista
# Inicio Item 2389
# Fim Item 2389
# Duração : 3.4865517616271973 segundos
# Faltam 1435 itens na lista
# Inicio Item 2390
# Fim Item 2390
# Duração : 3.3221867084503174 segundos
# Faltam 1434 itens na lista
# Inicio Item 2391
# Fim Item 2391
# Duração : 3.43306565284729 segundos
# Faltam 1433 itens na lista
# Inicio Item 2392
# Fim Item 2392
# Duração : 3.6202995777130127 segundos
# Faltam 1432 itens na lista
# Inicio Item 2393
# Fim Item 2393
# Duração : 3.4241573810577393 segundos
# Faltam 1431 itens na lista
# Inicio Item 2394
# Fim Item 2394
# Duração : 3.3765640258789062 segundos
# Faltam 1430 itens na lista
# Inicio Item 2395
# Fim Item 2395
# Duração : 3.425784111022949 segundos
# Faltam 1429 itens na lista
# Inicio Item 2396
# Fim Item 2396
# Duração : 3.3728420734405518 segundos
# Faltam 1428 itens na lista
# Inicio Item 2397
# Fim Item 2397
# Duração : 3.4188520908355713 segundos
# Faltam 1427 itens na lista
# Inicio Item 2398
# Fim Item 2398
# Duração : 3.781737804412842 segundos
# Faltam 1426 itens na lista
# Inicio Item 2399
# Fim Item 2399
# Duração : 3.441498041152954 segundos
# Faltam 1425 itens na lista
# Inicio Item 2400
# Fim Item 2400
# Duração : 3.491075038909912 segundos
# Faltam 1424 itens na lista
# Inicio Item 2401
# Fim Item 2401
# Duração : 3.6180851459503174 segundos
# Faltam 1423 itens na lista
# Inicio Item 2402
# Fim Item 2402
# Duração : 3.4709091186523438 segundos
# Faltam 1422 itens na lista
# Inicio Item 2403
# Fim Item 2403
# Duração : 3.480332374572754 segundos
# Faltam 1421 itens na lista
# Inicio Item 2404
# Fim Item 2404
# Duração : 3.4395835399627686 segundos
# Faltam 1420 itens na lista
# Inicio Item 2405
# Fim Item 2405
# Duração : 3.4265120029449463 segundos
# Faltam 1419 itens na lista
# Inicio Item 2406
# Fim Item 2406
# Duração : 3.3734889030456543 segundos
# Faltam 1418 itens na lista
# Inicio Item 2407
# Fim Item 2407
# Duração : 3.557687997817993 segundos
# Faltam 1417 itens na lista
# Inicio Item 2408
# Fim Item 2408
# Duração : 3.455615282058716 segundos
# Faltam 1416 itens na lista
# Inicio Item 2409
# Fim Item 2409
# Duração : 3.996936559677124 segundos
# Faltam 1415 itens na lista
# Inicio Item 2410
# Fim Item 2410
# Duração : 3.667072296142578 segundos
# Faltam 1414 itens na lista
# Inicio Item 2411
# Fim Item 2411
# Duração : 3.5023882389068604 segundos
# Faltam 1413 itens na lista
# Inicio Item 2412
# Fim Item 2412
# Duração : 3.495155096054077 segundos
# Faltam 1412 itens na lista
# Inicio Item 2413
# Fim Item 2413
# Duração : 3.5956804752349854 segundos
# Faltam 1411 itens na lista
# Inicio Item 2414
# Fim Item 2414
# Duração : 3.5105538368225098 segundos
# Faltam 1410 itens na lista
# Inicio Item 2415
# Fim Item 2415
# Duração : 3.9334259033203125 segundos
# Faltam 1409 itens na lista
# Inicio Item 2416
# Fim Item 2416
# Duração : 3.472242832183838 segundos
# Faltam 1408 itens na lista
# Inicio Item 2417
# Fim Item 2417
# Duração : 3.636352777481079 segundos
# Faltam 1407 itens na lista
# Inicio Item 2418
# Fim Item 2418
# Duração : 3.7641756534576416 segundos
# Faltam 1406 itens na lista
# Inicio Item 2419
# Fim Item 2419
# Duração : 3.5489513874053955 segundos
# Faltam 1405 itens na lista
# Inicio Item 2420
# Fim Item 2420
# Duração : 3.5242295265197754 segundos
# Faltam 1404 itens na lista
# Inicio Item 2421
# Fim Item 2421
# Duração : 3.5676560401916504 segundos
# Faltam 1403 itens na lista
# Inicio Item 2422
# Fim Item 2422
# Duração : 3.484639883041382 segundos
# Faltam 1402 itens na lista
# Inicio Item 2423
# Fim Item 2423
# Duração : 3.618352174758911 segundos
# Faltam 1401 itens na lista
# Inicio Item 2424
# Fim Item 2424
# Duração : 3.5936450958251953 segundos
# Faltam 1400 itens na lista
# Inicio Item 2425
# Fim Item 2425
# Duração : 3.6341445446014404 segundos
# Faltam 1399 itens na lista
# Inicio Item 2426
# Fim Item 2426
# Duração : 3.7215113639831543 segundos
# Faltam 1398 itens na lista
# Inicio Item 2427
# Fim Item 2427
# Duração : 3.661449432373047 segundos
# Faltam 1397 itens na lista
# Inicio Item 2428
# Fim Item 2428
# Duração : 3.515397310256958 segundos
# Faltam 1396 itens na lista
# Inicio Item 2429
# Fim Item 2429
# Duração : 3.6496341228485107 segundos
# Faltam 1395 itens na lista
# Inicio Item 2430
# Fim Item 2430
# Duração : 3.6993532180786133 segundos
# Faltam 1394 itens na lista
# Inicio Item 2431
# Fim Item 2431
# Duração : 4.3069469928741455 segundos
# Faltam 1393 itens na lista
# Inicio Item 2432
# Fim Item 2432
# Duração : 4.250771760940552 segundos
# Faltam 1392 itens na lista
# Inicio Item 2433
# Fim Item 2433
# Duração : 3.6480512619018555 segundos
# Faltam 1391 itens na lista
# Inicio Item 2434
# Fim Item 2434
# Duração : 3.9065053462982178 segundos
# Faltam 1390 itens na lista
# Inicio Item 2435
# Fim Item 2435
# Duração : 3.7718400955200195 segundos
# Faltam 1389 itens na lista
# Inicio Item 2436
# Fim Item 2436
# Duração : 3.992727756500244 segundos
# Faltam 1388 itens na lista
# Inicio Item 2437
# Fim Item 2437
# Duração : 3.700578451156616 segundos
# Faltam 1387 itens na lista
# Inicio Item 2438
# Fim Item 2438
# Duração : 3.739535093307495 segundos
# Faltam 1386 itens na lista
# Inicio Item 2439
# Fim Item 2439
# Duração : 3.6915500164031982 segundos
# Faltam 1385 itens na lista
# Inicio Item 2440
# Fim Item 2440
# Duração : 3.7689402103424072 segundos
# Faltam 1384 itens na lista
# Inicio Item 2441
# Fim Item 2441
# Duração : 3.7056922912597656 segundos
# Faltam 1383 itens na lista
# Inicio Item 2442
# Fim Item 2442
# Duração : 4.015621900558472 segundos
# Faltam 1382 itens na lista
# Inicio Item 2443
# Fim Item 2443
# Duração : 3.659104824066162 segundos
# Faltam 1381 itens na lista
# Inicio Item 2444
# Fim Item 2444
# Duração : 3.7193973064422607 segundos
# Faltam 1380 itens na lista
# Inicio Item 2445
# Fim Item 2445
# Duração : 3.7498867511749268 segundos
# Faltam 1379 itens na lista
# Inicio Item 2446
# Fim Item 2446
# Duração : 3.789088249206543 segundos
# Faltam 1378 itens na lista
# Inicio Item 2447
# Fim Item 2447
# Duração : 4.235167741775513 segundos
# Faltam 1377 itens na lista
# Inicio Item 2448
# Fim Item 2448
# Duração : 3.6566529273986816 segundos
# Faltam 1376 itens na lista
# Inicio Item 2449
# Fim Item 2449
# Duração : 3.83707594871521 segundos
# Faltam 1375 itens na lista
# Inicio Item 2450
# Fim Item 2450
# Duração : 4.907375335693359 segundos
# Faltam 1374 itens na lista
# Inicio Item 2451
# Fim Item 2451
# Duração : 3.8233113288879395 segundos
# Faltam 1373 itens na lista
# Inicio Item 2452
# Fim Item 2452
# Duração : 3.710902452468872 segundos
# Faltam 1372 itens na lista
# Inicio Item 2453
# Fim Item 2453
# Duração : 3.835718870162964 segundos
# Faltam 1371 itens na lista
# Inicio Item 2454
# Fim Item 2454
# Duração : 3.694763660430908 segundos
# Faltam 1370 itens na lista
# Inicio Item 2455
# Fim Item 2455
# Duração : 3.937046527862549 segundos
# Faltam 1369 itens na lista
# Inicio Item 2456
# Fim Item 2456
# Duração : 3.86871075630188 segundos
# Faltam 1368 itens na lista
# Inicio Item 2457
# Fim Item 2457
# Duração : 4.164610862731934 segundos
# Faltam 1367 itens na lista
# Inicio Item 2458
# Fim Item 2458
# Duração : 3.889554977416992 segundos
# Faltam 1366 itens na lista
# Inicio Item 2459
# Fim Item 2459
# Duração : 3.8589236736297607 segundos
# Faltam 1365 itens na lista
# Inicio Item 2460
# Fim Item 2460
# Duração : 3.9597883224487305 segundos
# Faltam 1364 itens na lista
# Inicio Item 2461
# Fim Item 2461
# Duração : 3.7986843585968018 segundos
# Faltam 1363 itens na lista
# Inicio Item 2462
# Fim Item 2462
# Duração : 4.089404582977295 segundos
# Faltam 1362 itens na lista
# Inicio Item 2463
# Fim Item 2463
# Duração : 4.1279966831207275 segundos
# Faltam 1361 itens na lista
# Inicio Item 2464
# Fim Item 2464
# Duração : 3.9165897369384766 segundos
# Faltam 1360 itens na lista
# Inicio Item 2465
# Fim Item 2465
# Duração : 4.224066972732544 segundos
# Faltam 1359 itens na lista
# Inicio Item 2466
# Fim Item 2466
# Duração : 3.866866111755371 segundos
# Faltam 1358 itens na lista
# Inicio Item 2467
# Fim Item 2467
# Duração : 3.957535743713379 segundos
# Faltam 1357 itens na lista
# Inicio Item 2468
# Fim Item 2468
# Duração : 3.947727918624878 segundos
# Faltam 1356 itens na lista
# Inicio Item 2469
# Fim Item 2469
# Duração : 4.0563554763793945 segundos
# Faltam 1355 itens na lista
# Inicio Item 2470
# Fim Item 2470
# Duração : 4.039340257644653 segundos
# Faltam 1354 itens na lista
# Inicio Item 2471
# Fim Item 2471
# Duração : 4.0628981590271 segundos
# Faltam 1353 itens na lista
# Inicio Item 2472
# Fim Item 2472
# Duração : 4.218875169754028 segundos
# Faltam 1352 itens na lista
# Inicio Item 2473
# Fim Item 2473
# Duração : 4.728452920913696 segundos
# Faltam 1351 itens na lista
# Inicio Item 2474
# Fim Item 2474
# Duração : 4.1077680587768555 segundos
# Faltam 1350 itens na lista
# Inicio Item 2475
# Fim Item 2475
# Duração : 3.919358968734741 segundos
# Faltam 1349 itens na lista
# Inicio Item 2476
# Fim Item 2476
# Duração : 4.018860340118408 segundos
# Faltam 1348 itens na lista
# Inicio Item 2477
# Fim Item 2477
# Duração : 4.553500652313232 segundos
# Faltam 1347 itens na lista
# Inicio Item 2478
# Fim Item 2478
# Duração : 4.011907577514648 segundos
# Faltam 1346 itens na lista
# Inicio Item 2479
# Fim Item 2479
# Duração : 4.903905391693115 segundos
# Faltam 1345 itens na lista
# Inicio Item 2480
# Fim Item 2480
# Duração : 3.9047038555145264 segundos
# Faltam 1344 itens na lista
# Inicio Item 2481
# Fim Item 2481
# Duração : 4.028186559677124 segundos
# Faltam 1343 itens na lista
# Inicio Item 2482
# Fim Item 2482
# Duração : 4.069538593292236 segundos
# Faltam 1342 itens na lista
# Inicio Item 2483
# Fim Item 2483
# Duração : 3.917689323425293 segundos
# Faltam 1341 itens na lista
# Inicio Item 2484
# Fim Item 2484
# Duração : 4.079400300979614 segundos
# Faltam 1340 itens na lista
# Inicio Item 2485
# Fim Item 2485
# Duração : 4.063280820846558 segundos
# Faltam 1339 itens na lista
# Inicio Item 2486
# Fim Item 2486
# Duração : 4.085031032562256 segundos
# Faltam 1338 itens na lista
# Inicio Item 2487
# Fim Item 2487
# Duração : 4.411656141281128 segundos
# Faltam 1337 itens na lista
# Inicio Item 2488
# Fim Item 2488
# Duração : 4.24785041809082 segundos
# Faltam 1336 itens na lista
# Inicio Item 2489
# Fim Item 2489
# Duração : 4.075404644012451 segundos
# Faltam 1335 itens na lista
# Inicio Item 2490
# Fim Item 2490
# Duração : 3.9696552753448486 segundos
# Faltam 1334 itens na lista
# Inicio Item 2491
# Fim Item 2491
# Duração : 4.355378150939941 segundos
# Faltam 1333 itens na lista
# Inicio Item 2492
# Fim Item 2492
# Duração : 4.249161243438721 segundos
# Faltam 1332 itens na lista
# Inicio Item 2493
# Fim Item 2493
# Duração : 4.2065253257751465 segundos
# Faltam 1331 itens na lista
# Inicio Item 2494
# Fim Item 2494
# Duração : 4.221417665481567 segundos
# Faltam 1330 itens na lista
# Inicio Item 2495
# Fim Item 2495
# Duração : 4.029860496520996 segundos
# Faltam 1329 itens na lista
# Inicio Item 2496
# Fim Item 2496
# Duração : 4.126261472702026 segundos
# Faltam 1328 itens na lista
# Inicio Item 2497
# Fim Item 2497
# Duração : 4.020440578460693 segundos
# Faltam 1327 itens na lista
# Inicio Item 2498
# Fim Item 2498
# Duração : 4.169992923736572 segundos
# Faltam 1326 itens na lista
# Inicio Item 2499
# Fim Item 2499
# Duração : 4.088645935058594 segundos
# Faltam 1325 itens na lista
# Inicio Item 2500
# Fim Item 2500
# Duração : 4.191197395324707 segundos
# Faltam 1324 itens na lista
# Inicio Item 2501
# Fim Item 2501
# Duração : 4.30844783782959 segundos
# ...
# Faltam 995 itens na lista
# Inicio Item 2830
# Fim Item 2830
# Duração : 7.970284938812256 segundos
# Faltam 994 itens na lista
# Inicio Item 2831
# Fim Item 2831
# Duração : 8.486402034759521 segundos
# Faltam 993 itens na lista
# Inicio Item 2832
# Fim Item 2832
# Duração : 8.365375280380249 segundos
# Faltam 992 itens na lista
# Inicio Item 2833
# Fim Item 2833
# Duração : 8.072947025299072 segundos
# Faltam 991 itens na lista
# Inicio Item 2834
# Fim Item 2834
# Duração : 9.099651098251343 segundos
# Faltam 990 itens na lista
# Inicio Item 2835
# Fim Item 2835
# Duração : 8.423752069473267 segundos
# Faltam 989 itens na lista
# Inicio Item 2836
# Fim Item 2836
# Duração : 8.071045160293579 segundos
# Faltam 988 itens na lista
# Inicio Item 2837
# Fim Item 2837
# Duração : 8.03420352935791 segundos
# Faltam 987 itens na lista
# Inicio Item 2838
# Fim Item 2838
# Duração : 8.17428469657898 segundos
# Faltam 986 itens na lista
# Inicio Item 2839
# Fim Item 2839
# Duração : 8.135143518447876 segundos
# Faltam 985 itens na lista
# Inicio Item 2840
# Fim Item 2840
# Duração : 8.061433792114258 segundos
# Faltam 984 itens na lista
# Inicio Item 2841
# Fim Item 2841
# Duração : 8.62528371810913 segundos
# Faltam 983 itens na lista
# Inicio Item 2842
# Fim Item 2842
# Duração : 8.631909132003784 segundos
# Faltam 982 itens na lista
# Inicio Item 2843
# Fim Item 2843
# Duração : 8.331714153289795 segundos
# Faltam 981 itens na lista
# Inicio Item 2844
# Fim Item 2844
# Duração : 8.022992610931396 segundos
# Faltam 980 itens na lista
# Inicio Item 2845
# Fim Item 2845
# Duração : 9.029000282287598 segundos
# Faltam 979 itens na lista
# Inicio Item 2846
# Fim Item 2846
# Duração : 9.785209655761719 segundos
# Faltam 978 itens na lista
# Inicio Item 2847
# Fim Item 2847
# Duração : 8.590739011764526 segundos
# Faltam 977 itens na lista
# Inicio Item 2848
# Fim Item 2848
# Duração : 8.739996433258057 segundos
# Faltam 976 itens na lista
# Inicio Item 2849
# Fim Item 2849
# Duração : 8.660833358764648 segundos
# Faltam 975 itens na lista
# Inicio Item 2850
# Fim Item 2850
# Duração : 8.232494592666626 segundos
# Faltam 974 itens na lista
# Inicio Item 2851
# Fim Item 2851
# Duração : 8.376556634902954 segundos
# Faltam 973 itens na lista
# Inicio Item 2852
# Fim Item 2852
# Duração : 8.295595169067383 segundos
# Faltam 972 itens na lista
# Inicio Item 2853
# Fim Item 2853
# Duração : 8.615196943283081 segundos
# Faltam 971 itens na lista
# Inicio Item 2854
# Fim Item 2854
# Duração : 8.260609865188599 segundos
# Faltam 970 itens na lista
# Inicio Item 2855
# Fim Item 2855
# Duração : 9.394267559051514 segundos
# Faltam 969 itens na lista
# Inicio Item 2856
# Fim Item 2856
# Duração : 9.389902114868164 segundos
# Faltam 968 itens na lista
# Inicio Item 2857
# Fim Item 2857
# Duração : 8.302103042602539 segundos
# Faltam 967 itens na lista
# Inicio Item 2858
# Fim Item 2858
# Duração : 8.47676706314087 segundos
# Faltam 966 itens na lista
# Inicio Item 2859
# Fim Item 2859
# Duração : 8.418076515197754 segundos
# Faltam 965 itens na lista
# Inicio Item 2860
# Fim Item 2860
# Duração : 9.171417713165283 segundos
# Faltam 964 itens na lista
# Inicio Item 2861
# Fim Item 2861
# Duração : 9.03161096572876 segundos
# Faltam 963 itens na lista
# Inicio Item 2862
# Fim Item 2862
# Duração : 9.689677238464355 segundos
# Faltam 962 itens na lista
# Inicio Item 2863
# Fim Item 2863
# Duração : 8.612959623336792 segundos
# Faltam 961 itens na lista
# Inicio Item 2864
# Fim Item 2864
# Duração : 8.344097137451172 segundos
# Faltam 960 itens na lista
# Inicio Item 2865
# Fim Item 2865
# Duração : 8.865192651748657 segundos
# Faltam 959 itens na lista
# Inicio Item 2866
# Fim Item 2866
# Duração : 8.721082925796509 segundos
# Faltam 958 itens na lista
# Inicio Item 2867
# Fim Item 2867
# Duração : 9.784170627593994 segundos
# Faltam 957 itens na lista
# Inicio Item 2868
# Fim Item 2868
# Duração : 8.933631658554077 segundos
# Faltam 956 itens na lista
# Inicio Item 2869
# Fim Item 2869
# Duração : 9.089550018310547 segundos
# Faltam 955 itens na lista
# Inicio Item 2870
# Fim Item 2870
# Duração : 9.150487899780273 segundos
# Faltam 954 itens na lista
# Inicio Item 2871
# Fim Item 2871
# Duração : 8.400475263595581 segundos
# Faltam 953 itens na lista
# Inicio Item 2872
# Fim Item 2872
# Duração : 8.424057722091675 segundos
# Faltam 952 itens na lista
# Inicio Item 2873
# Fim Item 2873
# Duração : 9.796525478363037 segundos
# Faltam 951 itens na lista
# Inicio Item 2874
# Fim Item 2874
# Duração : 8.80642056465149 segundos
# Faltam 950 itens na lista
# Inicio Item 2875
# Fim Item 2875
# Duração : 8.584406614303589 segundos
# Faltam 949 itens na lista
# Inicio Item 2876
# Fim Item 2876
# Duração : 8.786495447158813 segundos
# Faltam 948 itens na lista
# Inicio Item 2877
# Fim Item 2877
# Duração : 8.673909187316895 segundos
# Faltam 947 itens na lista
# Inicio Item 2878
# Fim Item 2878
# Duração : 8.473866939544678 segundos
# Faltam 946 itens na lista
# Inicio Item 2879
# Fim Item 2879
# Duração : 8.501869201660156 segundos
# Faltam 945 itens na lista
# Inicio Item 2880
# Fim Item 2880
# Duração : 9.117127656936646 segundos
# Faltam 944 itens na lista
# Inicio Item 2881
# Fim Item 2881
# Duração : 8.425914287567139 segundos
# Faltam 943 itens na lista
# Inicio Item 2882
# Fim Item 2882
# Duração : 8.965327739715576 segundos
# Faltam 942 itens na lista
# Inicio Item 2883
# Fim Item 2883
# Duração : 9.282169342041016 segundos
# Faltam 941 itens na lista
# Inicio Item 2884
# Fim Item 2884
# Duração : 9.554445743560791 segundos
# Faltam 940 itens na lista
# Inicio Item 2885
# Fim Item 2885
# Duração : 9.024463415145874 segundos
# Faltam 939 itens na lista
# Inicio Item 2886
# Fim Item 2886
# Duração : 8.649710178375244 segundos
# Faltam 938 itens na lista
# Inicio Item 2887
# Fim Item 2887
# Duração : 8.903762578964233 segundos
# Faltam 937 itens na lista
# Inicio Item 2888
# Fim Item 2888
# Duração : 8.603020668029785 segundos
# Faltam 936 itens na lista
# Inicio Item 2889
# Fim Item 2889
# Duração : 9.034766435623169 segundos
# Faltam 935 itens na lista
# Inicio Item 2890
# Fim Item 2890
# Duração : 9.007567644119263 segundos
# Faltam 934 itens na lista
# Inicio Item 2891
# Fim Item 2891
# Duração : 8.287542581558228 segundos
# Faltam 933 itens na lista
# Inicio Item 2892
# Fim Item 2892
# Duração : 8.721715450286865 segundos
# Faltam 932 itens na lista
# Inicio Item 2893
# Fim Item 2893
# Duração : 8.997992992401123 segundos
# Faltam 931 itens na lista
# Inicio Item 2894
# Fim Item 2894
# Duração : 9.371277093887329 segundos
# Faltam 930 itens na lista
# Inicio Item 2895
# Fim Item 2895
# Duração : 8.83187198638916 segundos
# Faltam 929 itens na lista
# Inicio Item 2896
# Fim Item 2896
# Duração : 10.49634337425232 segundos
# Faltam 928 itens na lista
# Inicio Item 2897
# Fim Item 2897
# Duração : 9.412623405456543 segundos
# Faltam 927 itens na lista
# Inicio Item 2898
# Fim Item 2898
# Duração : 8.995403051376343 segundos
# Faltam 926 itens na lista
# Inicio Item 2899
# Fim Item 2899
# Duração : 8.781646728515625 segundos
# Faltam 925 itens na lista
# Inicio Item 2900
# Fim Item 2900
# Duração : 9.242678165435791 segundos
# Faltam 924 itens na lista
# Inicio Item 2901
# Fim Item 2901
# Duração : 9.208828449249268 segundos
# Faltam 923 itens na lista
# Inicio Item 2902
# Fim Item 2902
# Duração : 9.674975156784058 segundos
# Faltam 922 itens na lista
# Inicio Item 2903
# Fim Item 2903
# Duração : 8.994688510894775 segundos
# Faltam 921 itens na lista
# Inicio Item 2904
# Fim Item 2904
# Duração : 8.765900135040283 segundos
# Faltam 920 itens na lista
# Inicio Item 2905
# Fim Item 2905
# Duração : 9.253370761871338 segundos
# Faltam 919 itens na lista
# Inicio Item 2906
# Fim Item 2906
# Duração : 9.629202604293823 segundos
# Faltam 918 itens na lista
# Inicio Item 2907
# Fim Item 2907
# Duração : 9.310531854629517 segundos
# Faltam 917 itens na lista
# Inicio Item 2908
# Fim Item 2908
# Duração : 8.678256273269653 segundos
# Faltam 916 itens na lista
# Inicio Item 2909
# Fim Item 2909
# Duração : 9.621259450912476 segundos
# Faltam 915 itens na lista
# Inicio Item 2910
# Fim Item 2910
# Duração : 9.34397554397583 segundos
# Faltam 914 itens na lista
# Inicio Item 2911
# Fim Item 2911
# Duração : 9.122880697250366 segundos
# Faltam 913 itens na lista
# Inicio Item 2912
# Fim Item 2912
# Duração : 8.867209434509277 segundos
# Faltam 912 itens na lista
# Inicio Item 2913
# Fim Item 2913
# Duração : 9.229583740234375 segundos
# Faltam 911 itens na lista
# Inicio Item 2914
# Fim Item 2914
# Duração : 9.115911483764648 segundos
# Faltam 910 itens na lista
# Inicio Item 2915
# Fim Item 2915
# Duração : 9.648780107498169 segundos
# Faltam 909 itens na lista
# Inicio Item 2916
# Fim Item 2916
# Duração : 9.341599225997925 segundos
# Faltam 908 itens na lista
# Inicio Item 2917
# Fim Item 2917
# Duração : 8.898577451705933 segundos
# Faltam 907 itens na lista
# Inicio Item 2918
# Fim Item 2918
# Duração : 8.713165044784546 segundos
# Faltam 906 itens na lista
# Inicio Item 2919
# Fim Item 2919
# Duração : 9.089287519454956 segundos
# Faltam 905 itens na lista
# Inicio Item 2920
# Fim Item 2920
# Duração : 9.31891679763794 segundos
# Faltam 904 itens na lista
# Inicio Item 2921
# Fim Item 2921
# Duração : 8.76134443283081 segundos
# Faltam 903 itens na lista
# Inicio Item 2922
# Fim Item 2922
# Duração : 9.753992557525635 segundos
# Faltam 902 itens na lista
# Inicio Item 2923
# Fim Item 2923
# Duração : 9.674403667449951 segundos
# Faltam 901 itens na lista
# Inicio Item 2924
# Fim Item 2924
# Duração : 9.742387056350708 segundos
# Faltam 900 itens na lista
# Inicio Item 2925
# Fim Item 2925
# Duração : 9.229976892471313 segundos
# Faltam 899 itens na lista
# Inicio Item 2926
# Fim Item 2926
# Duração : 9.18255352973938 segundos
# Faltam 898 itens na lista
# Inicio Item 2927
# Fim Item 2927
# Duração : 9.38525676727295 segundos
# Faltam 897 itens na lista
# Inicio Item 2928
# Fim Item 2928
# Duração : 10.076206922531128 segundos
# Faltam 896 itens na lista
# Inicio Item 2929
# Fim Item 2929
# Duração : 10.864121198654175 segundos
# Faltam 895 itens na lista
# Inicio Item 2930
# Fim Item 2930
# Duração : 9.158372163772583 segundos
# Faltam 894 itens na lista
# Inicio Item 2931
# Fim Item 2931
# Duração : 9.478370904922485 segundos
# Faltam 893 itens na lista
# Inicio Item 2932
# Fim Item 2932
# Duração : 9.935970067977905 segundos
# Faltam 892 itens na lista
# Inicio Item 2933
# Fim Item 2933
# Duração : 9.174360275268555 segundos
# Faltam 891 itens na lista
# Inicio Item 2934
# Fim Item 2934
# Duração : 11.981372594833374 segundos
# Faltam 890 itens na lista
# Inicio Item 2935
# Fim Item 2935
# Duração : 9.683618068695068 segundos
# Faltam 889 itens na lista
# Inicio Item 2936
# Fim Item 2936
# Duração : 9.225860834121704 segundos
# Faltam 888 itens na lista
# Inicio Item 2937
# Fim Item 2937
# Duração : 9.546254634857178 segundos
# Faltam 887 itens na lista
# Inicio Item 2938
# Fim Item 2938
# Duração : 9.960636854171753 segundos
# Faltam 886 itens na lista
# Inicio Item 2939
# Fim Item 2939
# Duração : 9.204976558685303 segundos
# Faltam 885 itens na lista
# Inicio Item 2940
# Fim Item 2940
# Duração : 10.166275262832642 segundos
# Faltam 884 itens na lista
# Inicio Item 2941
# Fim Item 2941
# Duração : 9.786246061325073 segundos
# Faltam 883 itens na lista
# Inicio Item 2942
# Fim Item 2942
# Duração : 9.098378896713257 segundos
# Faltam 882 itens na lista
# Inicio Item 2943
# Fim Item 2943
# Duração : 9.584312438964844 segundos
# Faltam 881 itens na lista
# Inicio Item 2944
# Fim Item 2944
# Duração : 10.545710802078247 segundos
# Faltam 880 itens na lista
# Inicio Item 2945
# Fim Item 2945
# Duração : 9.938076734542847 segundos
# Faltam 879 itens na lista
# Inicio Item 2946
# Fim Item 2946
# Duração : 9.792694807052612 segundos
# Faltam 878 itens na lista
# Inicio Item 2947
# Fim Item 2947
# Duração : 10.452040433883667 segundos
# Faltam 877 itens na lista
# Inicio Item 2948
# Fim Item 2948
# Duração : 10.274067878723145 segundos
# Faltam 876 itens na lista
# Inicio Item 2949
# Fim Item 2949
# Duração : 9.643837451934814 segundos
# Faltam 875 itens na lista
# Inicio Item 2950
# Fim Item 2950
# Duração : 10.45701551437378 segundos
# Faltam 874 itens na lista
# Inicio Item 2951
# Fim Item 2951
# Duração : 11.250652551651001 segundos
# Faltam 873 itens na lista
# Inicio Item 2952
# Fim Item 2952
# Duração : 10.142867088317871 segundos
# Faltam 872 itens na lista
# Inicio Item 2953
# Fim Item 2953
# Duração : 9.694687366485596 segundos
# Faltam 871 itens na lista
# Inicio Item 2954
# Fim Item 2954
# Duração : 9.548718929290771 segundos
# Faltam 870 itens na lista
# Inicio Item 2955
# Fim Item 2955
# Duração : 9.799256324768066 segundos
# Faltam 869 itens na lista
# Inicio Item 2956
# Fim Item 2956
# Duração : 11.592324018478394 segundos
# Faltam 868 itens na lista
# Inicio Item 2957
# Fim Item 2957
# Duração : 10.525497674942017 segundos
# Faltam 867 itens na lista
# Inicio Item 2958
# Fim Item 2958
# Duração : 10.239812850952148 segundos
# Faltam 866 itens na lista
# Inicio Item 2959
# Fim Item 2959
# Duração : 10.704063177108765 segundos
# Faltam 865 itens na lista
# Inicio Item 2960
# Fim Item 2960
# Duração : 9.643419742584229 segundos
# Faltam 864 itens na lista
# Inicio Item 2961
# Fim Item 2961
# Duração : 9.247450828552246 segundos
# Faltam 863 itens na lista
# Inicio Item 2962
# Fim Item 2962
# Duração : 9.927101850509644 segundos
# Faltam 862 itens na lista
# Inicio Item 2963
# Fim Item 2963
# Duração : 9.4503173828125 segundos
# Faltam 861 itens na lista
# Inicio Item 2964
# Fim Item 2964
# Duração : 10.34870171546936 segundos
# Faltam 860 itens na lista
# Inicio Item 2965
# Fim Item 2965
# Duração : 10.988675117492676 segundos
# Faltam 859 itens na lista
# Inicio Item 2966
# Fim Item 2966
# Duração : 10.096244812011719 segundos
# Faltam 858 itens na lista
# Inicio Item 2967
# Fim Item 2967
# Duração : 11.407233953475952 segundos
# Faltam 857 itens na lista
# Inicio Item 2968
# Fim Item 2968
# Duração : 9.99409294128418 segundos
# Faltam 856 itens na lista
# Inicio Item 2969
# Fim Item 2969
# Duração : 9.330857515335083 segundos
# Faltam 855 itens na lista
# Inicio Item 2970
# Fim Item 2970
# Duração : 10.352848052978516 segundos
# Faltam 854 itens na lista
# Inicio Item 2971
# Fim Item 2971
# Duração : 10.129542350769043 segundos
# Faltam 853 itens na lista
# Inicio Item 2972
# Fim Item 2972
# Duração : 9.630554437637329 segundos
# Faltam 852 itens na lista
# Inicio Item 2973
# Fim Item 2973
# Duração : 10.397859573364258 segundos
# Faltam 851 itens na lista
# Inicio Item 2974
# Fim Item 2974
# Duração : 10.793763399124146 segundos
# Faltam 850 itens na lista
# Inicio Item 2975
# Fim Item 2975
# Duração : 9.691339015960693 segundos
# Faltam 849 itens na lista
# Inicio Item 2976
# Fim Item 2976
# Duração : 10.611401081085205 segundos
# Faltam 848 itens na lista
# Inicio Item 2977
# Fim Item 2977
# Duração : 9.74764084815979 segundos
# Faltam 847 itens na lista
# Inicio Item 2978
# Fim Item 2978
# Duração : 9.468708515167236 segundos
# Faltam 846 itens na lista
# Inicio Item 2979
# Fim Item 2979
# Duração : 11.834917783737183 segundos
# Faltam 845 itens na lista
# Inicio Item 2980
# Fim Item 2980
# Duração : 11.187084674835205 segundos
# Faltam 844 itens na lista
# Inicio Item 2981
# Fim Item 2981
# Duração : 10.0139000415802 segundos
# Faltam 843 itens na lista
# Inicio Item 2982
# Fim Item 2982
# Duração : 10.507315635681152 segundos
# Faltam 842 itens na lista
# Inicio Item 2983
# Fim Item 2983
# Duração : 9.847895860671997 segundos
# Faltam 841 itens na lista
# Inicio Item 2984
# Fim Item 2984
# Duração : 9.905325174331665 segundos
# Faltam 840 itens na lista
# Inicio Item 2985
# Fim Item 2985
# Duração : 9.901702404022217 segundos
# Faltam 839 itens na lista
# Inicio Item 2986
# Fim Item 2986
# Duração : 10.023473501205444 segundos
# Faltam 838 itens na lista
# Inicio Item 2987
# Fim Item 2987
# Duração : 9.964823246002197 segundos
# Faltam 837 itens na lista
# Inicio Item 2988
# Fim Item 2988
# Duração : 10.3313627243042 segundos
# Faltam 836 itens na lista
# Inicio Item 2989
# Fim Item 2989
# Duração : 9.873574256896973 segundos
# Faltam 835 itens na lista
# Inicio Item 2990
# Fim Item 2990
# Duração : 11.795985460281372 segundos
# Faltam 834 itens na lista
# Inicio Item 2991
# Fim Item 2991
# Duração : 9.719240188598633 segundos
# Faltam 833 itens na lista
# Inicio Item 2992
# Fim Item 2992
# Duração : 11.038090229034424 segundos
# Faltam 832 itens na lista
# Inicio Item 2993
# Fim Item 2993
# Duração : 10.39823842048645 segundos
# Faltam 831 itens na lista
# Inicio Item 2994
# Fim Item 2994
# Duração : 10.430740594863892 segundos
# Faltam 830 itens na lista
# Inicio Item 2995
# Fim Item 2995
# Duração : 9.558428764343262 segundos
# Faltam 829 itens na lista
# Inicio Item 2996
# Fim Item 2996
# Duração : 10.017749547958374 segundos
# Faltam 828 itens na lista
# Inicio Item 2997
# Fim Item 2997
# Duração : 10.458048820495605 segundos
# Faltam 827 itens na lista
# Inicio Item 2998
# Fim Item 2998
# Duração : 10.68011999130249 segundos
# Faltam 826 itens na lista
# Inicio Item 2999
# Fim Item 2999
# Duração : 10.505592107772827 segundos

# %%
# Como a base de dados ficou muito grande, este comando e o seguinte devem ser rodados separadamente
# com limpeza de memória entre eles

from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent='teste_dengue')

clima = pd.DataFrame()


for i in dadosclima:
    if dadosclima.index(i) >= 3000:
        
 
        
        print('Faltam ' + str(len(dadosclima) - dadosclima.index(i) +1) +' itens na lista' )
        print('Inicio Item ' + str(dadosclima.index(i)))
        inicio = time.time()
        base1 = pd.read_csv(i, delimiter = ';',engine = 'python', nrows = 3)
        base2 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 3, nrows = 4)
        estado = base1.iloc[0,1]
        estacao = base1.iloc[1,1]
        lat = str(base2.iloc[0,1]).replace(',','.')
        long = str(base2.iloc[1,1]).replace(',','.')
        
        # Tratando casos onde temos latitude que começa apenas com . ou , (positivos e negativos)
        
        if lat[0] == '.':
            lat = str(0)+lat
        elif lat[0] == '-':
            lat = '-' + str(0) + lat[1:]
        else:
            pass
        if long[0] == '.':
            long = str(0)+long
        elif long[0] == '-':
            long = '-'+ str(0) + long [1:]                
        else: 
            pass
        
        # Passa as coordenadas 
        
        location = geolocator.reverse(lat +', ' + long)
        
        
         
        try:
            cidade = location.raw['address']['city'] 

        except:
            cidade = 'Erro'
            
        try:
            cep = location.raw['address']['postcode'] 
        except:
            cep = 'Erro'
        
        
        # Pega o restante da base, e adiciona colunas com os valores que descobrimos anteriormente
        
        base3 = pd.read_csv(i, delimiter = ';',engine = 'python', skiprows = 8)
        base3['estacao'] = estacao
        base3['estado'] = estado
        base3['cidade'] = pd.Series()
        base3['cep'] = pd.Series()
        base3['lat'] = lat
        base3['long'] = long
        
        
        try:
            base3['cidade'] = cidade

        except:
            pass
        
        try:
            base3['cep'] = cep
        except:
            pass
        
        
        
        clima = clima.append(base3)
        fim = time.time()
        tempo = fim - inicio

        print('Fim Item ' + str(dadosclima.index(i)))
        print('Duração : ' + str(tempo) + ' segundos')
        

    else:
        pass
    
clima.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part4.csv')
del clima

# %% [markdown]
# ### Carregando agora a base de casos de dengue
# ### Vamos seguir a estratégia: Com os dados de Dengue, tentar cruzar os dados com as bases de clima individualmente, para evitar de termos que consolidar uma base completa de clima que ficaria muito grande em memória.
#
# ### As cidades e Estados onde não conseguirmos dados de dengue x clima, iremos retirar da análise e assim faremos o filtro para tentar reduzir um pouco os dados possibilitando uso da memória para consolidar uma abt

# %%
#Primeiro pegando uma lista com todos os arquivos na pasta onde estão os dados

dadosdengue = []

import sys

root = r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue\DadosAnuaisCSV'
      
            
for root, dirs, files in os.walk(root):
     for file in files:
        dadosdengue.append(os.path.join(root, file))

# %%
#Casos de Dengue

#Criando um DataFrame

dengue = pd.DataFrame()


for i in dadosdengue:
    print(i)
    inicio = time.time()
    base1 = pd.read_csv(i, engine = 'python')
    dengue = dengue.append(base1, sort = False)
    fim = time.time()
    duracao = fim - inicio
    print(duracao)
    
dengue.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//dengue.csv')

# %%
dengue = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//dengue.csv')

# %%
notific_dengue = dengue[['DT_NOTIFIC','ID_MUNICIP','NU_ANO','NU_NOTIFIC']].groupby(['DT_NOTIFIC','NU_ANO','ID_MUNICIP']).agg('count').reset_index()

# %%
# Vamos usar o campo ID_MUNICIP posteriormente para fazer um join e descobrir o nome da cidade.
# Vamos transformar o campo em string para não termos problemas no join

notific_dengue['ID_MUNICIP'] = notific_dengue.ID_MUNICIP.apply(lambda x: str(x))

# %%
notific_dengue.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//notific_dengue.csv')

# %%
del dengue

# %% [markdown]
# ### Lendo agora a base de cidades
# ### Usaremos a base de cidades para identificar as cidades onde tivemos casos de dengue, para depois cruzar através da cidade os casos com os dados de clima

# %%
cidades = pd.read_excel(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Cidades//RELATORIO_DTB_BRASIL_DISTRITO.xls')

# %%
# Em uma das bases temos o código do município com 7 dígitos e em outra com 6, vamos igualar

cidades['ID_MUNICIP'] = cidades['Código Município Completo'].apply(lambda x: str(x)[:-1])

# %%
dengue_cidades = pd.merge(notific_dengue,cidades,how='inner',on='ID_MUNICIP')

# %%
# Deletando as bases anteriores para liberar memória

del cidades

# %%
dengue_cidades.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//denguecidades.csv')

# %% [markdown]
# # -------------------------------------------------
#
# # 3 . Tratando a base inicial de dados
#
# # --------------------------------------------------
#
#
#
#
# ### Temos todas as bases de dados que precisamos agora. Precisamos agregar e fazer join para começar a atacar o problema.
#
# ### Temos a base de clima com dados de hora em hora de todas as estações de medição espalhadas pelo Brasil
# ### Temos a base de número de notificações de dengue em cada cidade
#
# ### Para cruzar estas duas bases a chave será o nome da cidade e data
#
# ### A estratégia será verificar quantos cruzamentos temos de dados de clima x dengue para começar a análise

# %%
dengue_cidades = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Casos Dengue//denguecidades.csv')

# %%
dengue_cidades = dengue_cidades[['DT_NOTIFIC','ID_MUNICIP','NU_ANO','Nome_UF','Nome_Município','NU_NOTIFIC']]
dengue_cidades = dengue_cidades.drop_duplicates(subset = ['DT_NOTIFIC','ID_MUNICIP'])

# %%
states = {
    'AC': 'Acre',
    'AL': 'Alagoas',
    'AP': 'Amapá',
    'AM': 'Amazonas',
    'BA': 'Bahia',
    'CE': 'Ceará',
    'DF': 'Distrito Federal',
    'ES': 'Espírito Santo',
    'GO': 'Goiás',
    'MA': 'Maranhão',
    'MT': 'Mato Grosso',
    'MS': 'Mato Grosso do Sul',
    'MG': 'Minas Gerais',
    'PA': 'Pará',
    'PB': 'Paraíba',
    'PR': 'Paraná',
    'PE': 'Pernambuco',
    'PI': 'Piauí',
    'RJ': 'Rio de Janeiro',
    'RN': 'Rio Grande do Norte',
    'RS': 'Rio Grande do Sul',
    'RO': 'Rondônia',
    'RR': 'Roraima',
    'SC': 'Santa Catarina',
    'SP': 'São Paulo',
    'SE': 'Sergipe',
    'TO': 'Tocantins'
}

states = {v: k for k, v in states.items()}

# %%
dengue_cidades['UF'] = dengue_cidades['Nome_UF'].map(states)

# %% [markdown]
# ### Começando com as bases de clima

# %%
# Tratando os dados das bases.
# Começando pelo clima 1

clima1 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part1.csv')

# %%
# Como temos colunas com tipos diferentes de dados, vamos detectar o que está com tipos diferentes para poder tratar

for i in clima1.columns:
    print(clima1[i].apply(type).value_counts())

# %%
# Temos muitos dados sendo lidos como string, provavelmente por conta da virgula em campos numericos. 
# Vamos começar ajustando esse ponto
# Esta parte vai transformar colunas que são inteiras string para valores numéricos



for i in clima1.iloc[:,3:20].columns:
    
    
    print(i)
    clima1[i] = [float(x.replace(',','.')) if isinstance(x, str) else float(x) for x in clima1[i]]

    
# cidade e cep precisamos transformar para string

clima1.cidade = clima1.cidade.apply(lambda x: str(x))
clima1.cep = clima1.cep.apply(lambda x: str(x))


# for i in clima1.iloc[:,3:20].columns:
#     print(i)
#     print(type(clima1[i][0]))
#     if isinstance(clima1[i][0], str) == True:        
#         clima1[i] = clima1[i].apply(lambda x: float(x.replace(',','.')))
#         print(type(clima1[i][0]))
#     else: 
#         pass

# %%
# Vamos verificar se o tratamento foi efetivo

for i in clima1.columns:
    print(clima1[i].apply(type).value_counts())

# %%
# Agora que todos os valores estão devidamente tratados, vamos reduzir a base para facilitar o trabalho em memória
# Vamos reduzir a base a valores diários e não mais horários.

# Como o efeito da dengue será visto em dias, não há necessidade a princípio de termos dados de clima de hora em hora
# A tentativa será feita em cima de médias diárias


clima1_reduzida = clima1.groupby(['DATA (YYYY-MM-DD)','estado','cidade','cep','lat','long']).agg('mean').reset_index()
abt1 = pd.merge(clima1_reduzida,dengue_cidades, how = 'inner', left_on = ['DATA (YYYY-MM-DD)','estado','cidade'], right_on = ['DT_NOTIFIC','UF','Nome_Município'])

# %%
abt1.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt1.csv')

# %%
del clima1
del clima1_reduzida
del abt1

# %% [markdown]
# ### Vamos executar a mesma estratégia para as bases de clima 2, 3 e 4

# %% [markdown]
# ### Clima 2

# %%
# Tratando a base clima 2

clima2 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part2.csv')

# %%
# Como temos colunas com tipos diferentes de dados, vamos detectar o que está com tipos diferentes para poder tratar

for i in clima2.columns:
    print(clima2[i].apply(type).value_counts())

# %%
for i in clima2.iloc[:,3:20].columns:
    
    
    print(i)
    clima2[i] = [float(x.replace(',','.')) if isinstance(x, str) else float(x) for x in clima2[i]]
    
    
    
#     print(i)
#     print(type(clima2[i][0]))
#     if isinstance(clima2[i][0], str) == True:        
#         clima2[i] = clima2[i].apply(lambda x: float(x.replace(',','.')))
#         print(type(clima2[i][0]))
#     else: 
#         pass

# %%
# cidade e cep precisamos transformar para string

clima2.cidade = clima2.cidade.apply(lambda x: str(x))
clima2.cep = clima2.cep.apply(lambda x: str(x))

# %%
# Chegando se o tratamento foi efetivo

for i in clima2.columns:
    print(clima2[i].apply(type).value_counts())

# %%
# Agora que todos os valores estão devidamente tratados, vamos reduzir a base para facilitar o trabalho em memória
# Vamos reduzir a base a valores diários e não mais horários.

# Como o efeito da dengue será visto em dias, não há necessidade a princípio de termos dados de clima de hora em hora
# A tentativa será feita em cima de médias diárias


clima2_reduzida = clima2.groupby(['DATA (YYYY-MM-DD)','estado','cidade','cep','lat','long']).agg('mean').reset_index()
abt2 = pd.merge(clima2_reduzida,dengue_cidades, how = 'inner', left_on = ['DATA (YYYY-MM-DD)','estado','cidade'], right_on = ['DT_NOTIFIC','UF','Nome_Município'])

# %%
abt2.count()

# %%
abt2.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt2.csv')

# %%
del clima2
del clima2_reduzida
del abt2

# %% [markdown]
# ### Clima 3

# %%
# Agora para a base clima 3
# A partir da base clima 3, o INMET adiciona uma outra coluna de data diferente. No meio da base temos essa mudança no schema
# Teremos que tratar isso transformando tudo em uma coluna unica de data 

clima3 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part3.csv')
# Out:
# C:\Users\quadr\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (1,2,3,4,5,9,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
clima3.Data = clima3.Data.apply(lambda x: str(x))

clima3_part1 = clima3[clima3['DATA (YYYY-MM-DD)'].notnull()]
clima3_part2 = clima3[clima3['DATA (YYYY-MM-DD)'].isnull()]

# %%
# Tratando a coluna de Data

def ajuste_data(x : str):    
    return(x[:4]+'-'+x[5:7]+'-'+x[8:10])

# --------------------------------------------------

    
clima3_part2['DATA (YYYY-MM-DD)'] = clima3_part2.Data.apply(lambda x: ajuste_data(x))

clima3 = pd.concat([clima3_part1,clima3_part2], sort= False)
# Out:
# C:\Users\quadr\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
clima3 = clima3.drop('Data', axis = 1)
clima3 = clima3.drop('Hora UTC', axis = 1)

del clima3_part1
del clima3_part2

# %%
for i in clima3.iloc[:,3:21].columns:
    
    
    print(i)
    clima3[i] = [float(x.replace(',','.')) if isinstance(x, str) else float(x) for x in clima3[i]]
    
    
# cidade e cep precisamos transformar para string

clima3.cidade = clima3.cidade.apply(lambda x: str(x))
clima3.cep = clima3.cep.apply(lambda x: str(x))
# Out:
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)
# RADIACAO GLOBAL (W/m²)
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)
# TEMPERATURA DO PONTO DE ORVALHO (°C)
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
# UMIDADE RELATIVA DO AR, HORARIA (%)
# Unnamed: 19
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))
# VENTO, RAJADA MAXIMA (m/s)
# VENTO, VELOCIDADE HORARIA (m/s)

# %%
# Chegando se o tratamento foi efetivo

for i in clima3.columns:
    print(clima3[i].apply(type).value_counts())

# %%
# Agora que todos os valores estão devidamente tratados, vamos reduzir a base para facilitar o trabalho em memória
# Vamos reduzir a base a valores diários e não mais horários.

# Como o efeito da dengue será visto em dias, não há necessidade a princípio de termos dados de clima de hora em hora
# A tentativa será feita em cima de médias diárias


clima3_reduzida = clima3.groupby(['DATA (YYYY-MM-DD)','estado','cidade','cep','lat','long']).agg('mean').reset_index()
abt3 = pd.merge(clima3_reduzida,dengue_cidades, how = 'inner', left_on = ['DATA (YYYY-MM-DD)','estado','cidade'], right_on = ['DT_NOTIFIC','UF','Nome_Município'])

# %%
abt3.count()
# Out:
# DATA (YYYY-MM-DD)                                        39959
# estado                                                   39959
# cidade                                                   39959
# cep                                                      39959
# lat                                                      39959
# long                                                     39959
# Unnamed: 0                                               39959
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                         38337
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)    38900
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          38893
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         38893
# RADIACAO GLOBAL (W/m²)                                   38773
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)             38881
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     38632
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               38874
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               38874
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         38621
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         38621
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 38621
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 38621
# UMIDADE RELATIVA DO AR, HORARIA (%)                      38632
# Unnamed: 19                                                  0
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                     38103
# VENTO, RAJADA MAXIMA (m/s)                               38410
# VENTO, VELOCIDADE HORARIA (m/s)                          38422
# DT_NOTIFIC                                               39959
# ID_MUNICIP                                               39959
# NU_ANO                                                   39959
# Nome_UF                                                  39959
# Nome_Município                                           39959
# NU_NOTIFIC                                               39959
# UF                                                       39959
# dtype: int64

# %%
abt3.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt3.csv')

# %%
del clima3
del clima3_reduzida
del abt3

# %% [markdown]
# ### Clima 4

# %%
# Agora para a base clima 4

clima4 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Clima//clima_part4.csv')

# %%
# Tratando a coluna de Data

def ajuste_data(x : str):    
    return(x[:4]+'-'+x[5:7]+'-'+x[8:10])

# --------------------------------------------------

    
clima4.Data = clima4.Data.apply(lambda x: ajuste_data(x))
clima4 = clima4.rename(columns={'Data': 'DATA (YYYY-MM-DD)'})

# %%
for i in clima4.iloc[:,3:21].columns:
    
    
    print(i)
    clima4[i] = [float(x.replace(',','.')) if isinstance(x, str) else float(x) for x in clima4[i]]
    
    
# cidade e cep precisamos transformar para string

clima4.cidade = clima4.cidade.apply(lambda x: str(x))
clima4.cep = clima4.cep.apply(lambda x: str(x))

# %%
# Chegando se o tratamento foi efetivo

for i in clima4.columns:
    print(clima4[i].apply(type).value_counts())

# %%
# Agora que todos os valores estão devidamente tratados, vamos reduzir a base para facilitar o trabalho em memória
# Vamos reduzir a base a valores diários e não mais horários.

# Como o efeito da dengue será visto em dias, não há necessidade a princípio de termos dados de clima de hora em hora
# A tentativa será feita em cima de médias diárias


clima4_reduzida = clima4.groupby(['DATA (YYYY-MM-DD)','estado','cidade','cep','lat','long']).agg('mean').reset_index()
abt4 = pd.merge(clima4_reduzida,dengue_cidades, how = 'inner', left_on = ['DATA (YYYY-MM-DD)','estado','cidade'], right_on = ['DT_NOTIFIC','UF','Nome_Município'])

# %%
abt4.count()

# %%
abt4.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt4.csv')

# %% [markdown]
# # -----------------------------------------------------------

# %% [markdown]
# ### Finalizando a ABT empilhando os dados
#
# ### Até então o que poderíamos tirar de informação das bases foi retirado. O Refinamento da informação será feito no próximo notebook antes da análise exploratória

# %%
abt1 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt1.csv')
abt2 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt2.csv')
abt3 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt3.csv')
abt4 = pd.read_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt4.csv')

# %%
abt1.columns

# %%
abt2.columns

# %%
abt3.columns

# %%
abt4.columns

# %%
abt_final = pd.concat([abt1,abt2], sort=False)

# %%
abt3 = abt3[['Unnamed: 0', 'DATA (YYYY-MM-DD)', 'estado', 'cidade', 'cep', 'lat',
       'long', 'Unnamed: 0.1', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (W/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)', 'Unnamed: 19', 'DT_NOTIFIC',
       'ID_MUNICIP', 'NU_ANO', 'Nome_UF', 'Nome_Município', 'NU_NOTIFIC']]

# %%
abt4 = abt4[['Unnamed: 0', 'DATA (YYYY-MM-DD)', 'estado', 'cidade', 'cep', 'lat',
       'long', 'Unnamed: 0.1', 'PRECIPITAÇÃO TOTAL, HORÁRIO (mm)',
       'PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)',
       'PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
       'PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
       'RADIACAO GLOBAL (W/m²)',
       'TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)',
       'TEMPERATURA DO PONTO DE ORVALHO (°C)',
       'TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)',
       'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)',
       'UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)',
       'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
       'UMIDADE RELATIVA DO AR, HORARIA (%)',
       'VENTO, DIREÇÃO HORARIA (gr) (° (gr))', 'VENTO, RAJADA MAXIMA (m/s)',
       'VENTO, VELOCIDADE HORARIA (m/s)', 'Unnamed: 19', 'DT_NOTIFIC',
       'ID_MUNICIP', 'NU_ANO', 'Nome_UF', 'Nome_Município', 'NU_NOTIFIC']]

# %%
abt_final = pd.concat([abt_final,abt3,abt4], sort = False)

# %%
abt_final.to_csv(r'E:\Users\quadr\Documents\MBA\Trabalhos\TCC\Dengue\Bases\Bases Tratadas//abt_final.csv')
